# %% [markdown]
# ## Simple GPT2 Impelmentation
#
# This notebook implements a simple GPT2 model based on the archicture from:
#
# Improving Language Understanding by Generative Pre-Training (OpenAI)
#
# Also useful for tranformers:
#
# Attention Is All You Need (Google Brain)
#
# Weight tying between the embeddings and softmax layer:
#
# Using the Output Embedding to Improve Language Models

# %% [markdown]
# The code in this notebook is heavily annotated which detrements readability but hopefully helps explain how the multi-head attention is implemented using PyTorch

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from dataclasses import dataclass
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, Subset
from torch.nn import functional as F
from sklearn.model_selection import train_test_split
from typing import Tuple

torch.manual_seed(1)

# %%
class Text_Handler:
    
    def __init__(self, file_name, context_length):
        self.context_length = context_length 
        assert self.context_length != 0
        self.raw_text = self.load_text(file_name)
        self.vocab_size, self.stoi, self.itos = self.pre_process_text()
        self.encode = lambda s: [self.stoi[c] for c in s]
        self.decode = lambda l: "".join([self.itos[i] for i in l])
        
        # Load, split without shuffle and make context length exmaples.
        self.text = torch.tensor(self.encode(self.raw_text), dtype=torch.long)
        self.train_text, self.test_text = train_test_split(self.text, test_size=0.2, shuffle=False)
        self.X_train, self.Y_train = self.make_examples(self.train_text)
        self.X_test, self.Y_test = self.make_examples(self.test_text)
        
        self.train_dataset = TensorDataset(self.X_train, self.Y_train)
        self.test_dataset = TensorDataset(self.X_test, self.Y_test)
                
    def load_text(self, file_name): 
        try:
            with open(file_name, "r") as f:
                return f.read()
        except FileNotFoundError:
            raise FileNotFoundError(f"File {file_name} does not exist within the working directory.")
            
    def pre_process_text(self):
        chars = sorted(list(set(self.raw_text)))
        vocab_size = len(chars)
        stoi = {char: i for i, char in enumerate(chars)}
        itos = {i: char for char, i in stoi.items()}
        return vocab_size, stoi, itos
    
    def make_examples(self, text: torch.Tensor, verbose=False) -> Tuple[torch.Tensor, torch.Tensor]:
        n_examples = text.shape[0] - self.context_length
        X = torch.empty(n_examples, self.context_length, dtype=torch.long)
        Y = torch.empty(n_examples, dtype=torch.long)

        for i in range(n_examples):
            X[i] = text[i: i + self.context_length]
            Y[i] = text[i + self.context_length]
            if verbose: print(f"Example {i+1:2d}: {X[i].tolist()} --> {Y[i].item()}")

        return X, Y

# %%
# GPT2 implementation

class Causal_Self_Attention(nn.Module):
    
    def __init__(self, config):
        super().__init__()
        # Make sure we can project the embeddings across the attention heads:
        assert config.n_embd % config.n_head == 0
        self.n_head = config.n_head
        self.n_embd = config.n_embd # = model dimension
        
        # Layer to generate keys, queries, values in one pass:
        self.attn = nn.Linear(config.n_embd, 3 * config.n_embd)
        self.attn_dropout = nn.Dropout(config.dropout)
        
        # Make sure the causal mask is saved to the state dict and is moved with the model to the GPU. 
        self.register_buffer("causal_mask", torch.tril(torch.ones(config.context_length, config.context_length))
                                    .view(1, 1, config.context_length, config.context_length))
        
        # Final lienar transfromation after multi-head attention
        self.proj = nn.Linear(config.n_embd, config.n_embd, bias=config.bias)
        self.proj_dropout = nn.Dropout(config.dropout)
    
    def forward(self, x):

        # batch size = number of graphs processed at once 
        # context legnth = number of nodes in the graph
        # channels = embedding dimensionality of each node = attention_component_size
        n_graphs, n_nodes, attention_component_size = x.size() 
        
        # Calculate the keys, queries and values of all the nodes in each graph using the nodes' embeddings.
        # Each component q,k,v remains the same size as the embedding dimensionality: n_embd = size_components q,k,v.
        queries, keys, values  = self.attn(x).split(self.n_embd, dim=2) # Each have: (n_graphs, n_nodes, size_components=n_embd)
        
        # Split each node and its attention components across the heads (= project the The "key", "query", and "value"s across the heads):
    
        # (n_graphs, n_nodes, size_components) -> (n_graphs, n_nodes, n_heads, size_components/n_heads = split_information)^T(1,2) -> (n_graphs, n_heads, n_nodes, split_information)
        queries = queries.view(n_graphs, n_nodes, self.n_head, attention_component_size // self.n_head).transpose(1, 2)
        keys = keys.view(n_graphs, n_nodes, self.n_head, attention_component_size // self.n_head).transpose(1, 2)
        values = values.view(n_graphs, n_nodes, self.n_head, attention_component_size // self.n_head).transpose(1, 2)
        
        
        # Implement scaled dot product attention for graph in each attention head. 
        # i.e. how all the nodes talk to eachother when their info is split across the heads: (attention_component_size // self.n_head). 
        # This "split_information" is the dimension which is dot producted over in each graph, leaving: 
        # --> n_heads * n_nodes * n_nodes ! i.e. in each head you have n_nodes talking to n_nodes. 
        
    
        # For each graph in each head: (n_nodes, split_information) * (n_nodes, split_information)^T
        # (n_graphs, n_heads, n_nodes, split_information) * (n_graphs, n_heads, split_information, n_nodes) -> (n_graphs, n_heads, n_nodes, n_nodes)
        # Normalise by the size of the split_information.
        att = (queries @ keys.transpose(-2, -1)) * (1.0 / math.sqrt(keys.size(-1)))
        
        
        # Apply the causal mask to each graph.  
        # The indexing here allows us to handle sequences shorter than the full context length. 
        att = att.masked_fill(self.causal_mask[:,:,:n_nodes,:n_nodes] == 0, float('-inf'))
        
        # Softmax across how each node talks to the nodes causally connected to it.
        # For each node this leaves a "fraction of my attention I will pay to each other nodes' value vector" for each node in the graph.
        attention_fractions = self.attn_dropout(F.softmax(att, dim=-1))
        
        attention_weighted_value_vectors = attention_fractions @ values
        
        # Recombine all the heads' attention_weighted_value_vectors.
        # Ensure this is in contigious memory.
        attention_weighted_value_vectors = attention_weighted_value_vectors.transpose(1, 2).contiguous().view(n_graphs, n_nodes, attention_component_size)
        
        # Apply the final linear transforamtion to leave the output with the same dimensions as the input for a residual connection.
        out = self.proj_dropout(self.proj(attention_weighted_value_vectors))
        
        return out

# %%
class Multi_Layer_Perceptron(nn.Module):

    def __init__(self, config):
        super().__init__()
        # 4X step up as in the paper, and GeLu to stop dead neurons.
        self.fc    = nn.Linear(config.n_embd, 4 * config.n_embd, bias=config.bias)
        self.proj  = nn.Linear(4 * config.n_embd, config.n_embd, bias=config.bias)
        self.nonlin = nn.GELU()

    def forward(self, x):
        x = self.fc(x)
        x = self.nonlin(x)
        x = self.proj(x)
        return x

# %%
class Block(nn.Module):

    def __init__(self, config):
        super().__init__()
        # Normalise before and after the self attention as in the paper. 
        self.ln_1 = nn.LayerNorm(config.n_embd)
        self.attn = Causal_Self_Attention(config)
        self.ln_2 = nn.LayerNorm(config.n_embd)
        self.mlp = Multi_Layer_Perceptron(config)

    def forward(self, x):
        x = x + self.attn(self.ln_1(x))
        x = x + self.mlp(self.ln_2(x))
        return x

# %%
class GPT(nn.Module):
    
    def __init__(self, config):
        super().__init__()
        assert config.vocab_size is not None
        assert config.context_length is not None
        self.config = config
        
        self.transformer = nn.ModuleDict(dict(
            token_embd = nn.Embedding(config.vocab_size, config.n_embd),
            positional_embd = nn.Embedding(config.n_embd, config.n_embd),
            attention_stack = nn.ModuleList([Block(config) for _ in range(config.n_layer)]),
            final_ln = nn.LayerNorm(config.n_embd)))
        
        self.output_head = nn.Linear(config.n_embd, config.vocab_size, bias=False)
        
        # The output head and the token embeddings have the same dimension.
        # So both learn vector representaions of tokens.
        # Paper: "We study the topmost weight matrix of neural network language models. 
        # We show that this matrix constitutes a validword embedding."
        # PyTorch accumululates (adds) the gradients of both together in a backwards pass.
        self.transformer.positional_embd.weight = self.output_head.weight
        
        self.apply(self._init_weights)
        
        # Apply special scaled init to the residual projections, per GPT-2 paper
        for name, param in self.named_parameters():
            if name.endswith('proj.weight'):
                torch.nn.init.normal_(param, mean=0.0, std=0.02/math.sqrt(2 * config.n_layer))
        
        # Print the number of parameters
        print("number of parameters: %d" % (sum(p.nelement() for p in self.parameters()),))
    
    def _init_weights(self, module):
        # "Since layernorm [2] is used extensively throughout the model, a simple weight initialization of 
        # N(0, 0.02) was sufficient."
        
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
                
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
                
    def forward(self, seq):
        device = seq.device
        n_graphs, n_nodes = seq.size()
        assert n_nodes<= self.config.context_length, f"Cannot forward sequence {seq} of length {n_nodes} as it exceeds the maximum context legnth {self.config.context_length}."
        positions = torch.arange(0, n_nodes, dtype=torch.long, device=device).unsqueeze(dim=0)
        
        token_embd = self.transformer.token_embd(seq)
        positional_embd = self.transformer.positional_embd(positions)
        
        # x = embedded graph
        x = token_embd + positional_embd
        
        # residual attention stack 
        for block in self.transformer.attention_stack:
            x = block(x)
        x = self.transformer.final_ln(x)

        # output head gives the distribution for the next token so we want
        # to predict 0,..., n | here so we feed it only the last time step (n or -1)
        logits = self.output_head(x[:, -1, :]) # only logits of the last time step over the vocab space.
        return logits

# %%
@dataclass
class GPTConfig:
    # Default GPT-2 hyperparameters from the paper
    context_length: int = 1024
    vocab_size: int = 50304
    n_layer: int = 12
    n_head: int = 12
    n_embd: int = 768
    dropout: float = 0.1
    bias: bool = False

# %%
context_length = 24 # or number of nodes in the communication graph 
d = Text_Handler("input_shakespeare.txt", context_length)

# %%
context_length = 24 # or number of nodes in the communication graph 
d = Text_Handler("input_shakespeare.txt", context_length)
config = GPTConfig(
    context_length = context_length,
    vocab_size = d.vocab_size,
    n_layer = 4,
    n_head = 3,
    n_embd = 24,
    dropout = 0.1,
    bias = False)

# %%
from_scratch = False

if not from_scratch:
    # Load the saved model, optimiser state, and losses from checkpoint
    checkpoint = torch.load('shakespeare_GPT.pth')
    config = checkpoint['config']

    model = GPT(config)
    model.load_state_dict(checkpoint['model_state_dict'])
    
    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-1)
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    
    losses = checkpoint['losses']
    
else:
    # start from scratch
    model = GPT(config)
    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-1)
    losses = []
# Out:
# number of parameters: 31488

# %%
def moving_average(data, window_size):
    series = pd.Series(data)
    moving_avg = series.rolling(window=window_size).mean()
    return moving_avg.tolist()

plt.plot(moving_average(losses,1000))

# %%
class Trainer:
    def __init__(self, text_handler, save_path, config=None, load_path=None):
        self.load_checkpoint(load_path)
        self.text_handler = text_handler
        self.save_path = save_path
        
    def load_checkpoint(self, path):
        if path is not None:
            # Load the saved model, optimiser state, and losses from checkpoint
            checkpoint = torch.load(path)
            self.config = checkpoint['config']

            self.model = GPT(config)
            self.model.load_state_dict(checkpoint['model_state_dict'])
            
            self.optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-1)
            self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
            
            self.train_losses = checkpoint['train_losses']
            self.test_losses = checkpoint['test_losses']
            
            self.plot_loss(smoothing_window=1000)
            
        else:
            # Start from scratch
            assert config is not None, "You must provide a configuration for the GPT if training from scratch."
            self.model = GPT(config)
            self.optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-1)
            self.train_losses = []
            self.test_losses = []
    
    @torch.no_grad()
    def test_loss(self, frac_of_test_data):
        data_loader = DataLoader(self.text_handler.test_dataset, batch_size=bs, shuffle=False)
        test_loader = Subset(data_loader, range(len(data_loader)*frac_of_test_data))
        model.eval()
        losses = []
        for X_batch, y_batch in test_loader:
                logits = model(X_batch)
                loss = F.cross_entropy(logits, y_batch)
                losses.append(loss.item())
                self.test.losses.append(loss.item())
        
        print(f"Mean Test Loss: {np.array(losses).mean():.3f}")
        model.train()
        
    def train(self, n_epochs, bs, frac_of_train_data, test_freq, frac_of_test_data):
        model.train()
        data_loader = DataLoader(self.text_handler.train_dataset, batch_size=bs, shuffle=True)
        n_batches = int(len(data_loader) * frac_of_test_data)
        train_loader = Subset(data_loader, range(n_batches))
        for epoch in range(n_epochs):
                for batch_idx, (X_batch, y_batch) in enumerate(train_loader):
                    logits = self.model(X_batch)
                    loss = F.cross_entropy(logits, y_batch)
                    self.optimizer.zero_grad()
                    loss.backward()
                    self.optimizer.step()
                    self.train_losses.append(loss.item())
                    if batch_idx % eval_freq: 
                        self.test_loss(frac_of_test_data)
                    print(f"Epoch: {epoch}, Batch: {batch_idx}, Loss: {loss.item():.3f}")
        
        self.plot_loss(smoothing_window=1000)            
        self.save_checkpoint()
        
    def generate_text(starting_seq, temp, n_steps):
        
        encoded_seq = self.text_handler.encode(starting_seq)
        working_seq = encoded_seq.copy()
        
        model.eval()
        for _ in range(n_steps):
            x = torch.tensor(working_seq, dtype=torch.long).unsqueeze(dim=0)
            logits = self.model(x)
            # apply a temperature to chnage the shape of the next token distribution 
            logits = logits / temp
            probs = nn.functional.softmax(logits, dim=-1)
            # sample from the distribution
            next_token = torch.multinomial(probs[0], num_samples=1).item()
            encoded_seq.append(next_token)
            working_seq = working_seq[1:] + [next_token]

        print(self.text_handler.decode(encoded_seq))

    def save_checkpoint(self):
        model.eval()            
        torch.save({'model_state_dict': model.state_dict(),
                    'config': config,
                    'optimizer_state_dict': optimizer.state_dict(),
                    'train_losses': train_losses,
                    'test_losses': test_losses}, self.save_path)
        
    @staticmethod
    def moving_average(data, window_size):
        series = pd.Series(data)
        moving_avg = series.rolling(window=window_size).mean()
        return moving_avg.tolist()
    
    def plot_loss(self, smoothing_window):
        fig, ax = plt.subplots(nrows=1, ncols=2)
        ax[0].plot(moving_average(self.train_losses, smoothing_window))
        ax[1].plot(moving_average(self.test_losses, int(smoothing_window/100)))
        ax[0].set_ylabel("Training loss")
        ax[1].set_ylabel("Test loss")

# %%
# Preproccess the raw text
context_length = 24 # or number of nodes in the communication graph 
text_handler = Text_Handler("input_shakespeare.txt", context_length)

# %%
# Train setup
save_path = 'shakespeare_GPT.pth'

config = GPTConfig(
    context_length = context_length,
    vocab_size = text_handler.vocab_size,
    n_layer = 6,
    n_head = 4,
    n_embd = 24,
    dropout = 0.1,
    bias = False)

model_trainer = Trainer(text_handler, save_path, config)
# Out:
# number of parameters: 45648

# %%
# Train
bs = 32
n_epochs = 1
frac_of_train_data = 0.1
test_freq = 10 # training batches
frac_of_train_data = 0.1

model_trainer.train(n_epochs, bs, frac_of_train_data, test_freq, frac_of_train_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [226], in <cell line: 8>()
#       5 test_freq = 10 # training batches
#       6 frac_of_train_data = 0.1
# ----> 8 model_trainer.train(n_epochs, bs, frac_of_train_data, test_freq, frac_of_train_data)
#
# Input In [221], in Trainer.train(self, n_epochs, bs, frac_of_train_data, test_freq, frac_of_test_data)
#      51 train_loader = Subset(data_loader, range(n_batches))
#      52 for epoch in range(n_epochs):
# ---> 53         for batch_idx, (X_batch, y_batch) in enumerate(train_loader):
#      54             logits = self.model(X_batch)
#      55             loss = F.cross_entropy(logits, y_batch)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataset.py:290, in Subset.__getitem__(self, idx)
#     288 if isinstance(idx, list):
#     289     return self.dataset[[self.indices[i] for i in idx]]
# --> 290 return self.dataset[self.indices[idx]]
#
# TypeError: 'DataLoader' object is not subscriptable

# %%
bs = 32
n_epochs = 1
data_loader = DataLoader(d.train_dataset, batch_size=bs, shuffle=True)
print(f"Number of mini-batches {len(data_loader)}")
# losses = []

model.train()
for epoch in range(n_epochs):
        for batch_idx, (X_batch, y_batch) in enumerate(data_loader):
            logits = model(X_batch)
            loss = F.cross_entropy(logits, y_batch)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            losses.append(loss.item())
            print(f"Epoch: {epoch}, Batch: {batch_idx}, Loss: {loss.item():.3f}")
            
model.eval()            
torch.save({'model_state_dict': model.state_dict(),
            'config': config,
            'optimizer_state_dict': optimizer.state_dict(),
            'losses': losses}, 'shakespeare_GPT.pth')

plt.plot(moving_average(losses,1000))
# Out:
# Number of mini-batches 27885
# Epoch: 0, Batch: 0, Loss: 2.065
# Epoch: 0, Batch: 1, Loss: 2.315
# Epoch: 0, Batch: 2, Loss: 2.140
# Epoch: 0, Batch: 3, Loss: 2.194
# Epoch: 0, Batch: 4, Loss: 2.320
# Epoch: 0, Batch: 5, Loss: 1.868
# Epoch: 0, Batch: 6, Loss: 1.971
# Epoch: 0, Batch: 7, Loss: 2.776
# Epoch: 0, Batch: 8, Loss: 1.771
# Epoch: 0, Batch: 9, Loss: 2.230
# Epoch: 0, Batch: 10, Loss: 1.930
# Epoch: 0, Batch: 11, Loss: 1.973
# Epoch: 0, Batch: 12, Loss: 2.049
# Epoch: 0, Batch: 13, Loss: 2.101
# Epoch: 0, Batch: 14, Loss: 2.248
# Epoch: 0, Batch: 15, Loss: 1.834
# Epoch: 0, Batch: 16, Loss: 2.025
# Epoch: 0, Batch: 17, Loss: 1.908
# Epoch: 0, Batch: 18, Loss: 1.920
# Epoch: 0, Batch: 19, Loss: 2.069
# Epoch: 0, Batch: 20, Loss: 2.171
# Epoch: 0, Batch: 21, Loss: 2.255
# Epoch: 0, Batch: 22, Loss: 1.592
# Epoch: 0, Batch: 23, Loss: 1.739
# Epoch: 0, Batch: 24, Loss: 2.277
# Epoch: 0, Batch: 25, Loss: 2.613
# Epoch: 0, Batch: 26, Loss: 2.467
# Epoch: 0, Batch: 27, Loss: 1.989
# Epoch: 0, Batch: 28, Loss: 1.762
# Epoch: 0, Batch: 29, Loss: 2.216
# Epoch: 0, Batch: 30, Loss: 2.448
# Epoch: 0, Batch: 31, Loss: 1.826
# Epoch: 0, Batch: 32, Loss: 2.158
# Epoch: 0, Batch: 33, Loss: 2.000
# Epoch: 0, Batch: 34, Loss: 2.156
# Epoch: 0, Batch: 35, Loss: 2.061
# Epoch: 0, Batch: 36, Loss: 2.010
# Epoch: 0, Batch: 37, Loss: 2.529
# Epoch: 0, Batch: 38, Loss: 2.196
# Epoch: 0, Batch: 39, Loss: 1.703
# Epoch: 0, Batch: 40, Loss: 2.321
# Epoch: 0, Batch: 41, Loss: 1.878
# Epoch: 0, Batch: 42, Loss: 2.148
# Epoch: 0, Batch: 43, Loss: 1.985
# Epoch: 0, Batch: 44, Loss: 2.224
# Epoch: 0, Batch: 45, Loss: 2.057
# Epoch: 0, Batch: 46, Loss: 1.709
# Epoch: 0, Batch: 47, Loss: 2.119
# Epoch: 0, Batch: 48, Loss: 2.198
# Epoch: 0, Batch: 49, Loss: 1.931
# Epoch: 0, Batch: 50, Loss: 2.201
# Epoch: 0, Batch: 51, Loss: 2.295
# Epoch: 0, Batch: 52, Loss: 1.942
# Epoch: 0, Batch: 53, Loss: 2.016
# Epoch: 0, Batch: 54, Loss: 1.990
# Epoch: 0, Batch: 55, Loss: 2.392
# Epoch: 0, Batch: 56, Loss: 2.127
# Epoch: 0, Batch: 57, Loss: 1.829
# Epoch: 0, Batch: 58, Loss: 2.261
# Epoch: 0, Batch: 59, Loss: 2.253
# Epoch: 0, Batch: 60, Loss: 2.140
# Epoch: 0, Batch: 61, Loss: 1.901
# Epoch: 0, Batch: 62, Loss: 1.730
# Epoch: 0, Batch: 63, Loss: 1.934
# Epoch: 0, Batch: 64, Loss: 2.417
# Epoch: 0, Batch: 65, Loss: 2.118
# Epoch: 0, Batch: 66, Loss: 1.973
# Epoch: 0, Batch: 67, Loss: 2.356
# Epoch: 0, Batch: 68, Loss: 1.986
# Epoch: 0, Batch: 69, Loss: 2.078
# Epoch: 0, Batch: 70, Loss: 2.478
# Epoch: 0, Batch: 71, Loss: 2.383
# Epoch: 0, Batch: 72, Loss: 1.677
# Epoch: 0, Batch: 73, Loss: 2.649
# Epoch: 0, Batch: 74, Loss: 1.998
# Epoch: 0, Batch: 75, Loss: 2.178
# Epoch: 0, Batch: 76, Loss: 1.761
# Epoch: 0, Batch: 77, Loss: 2.248
# Epoch: 0, Batch: 78, Loss: 1.827
# Epoch: 0, Batch: 79, Loss: 1.732
# Epoch: 0, Batch: 80, Loss: 2.474
# Epoch: 0, Batch: 81, Loss: 2.435
# Epoch: 0, Batch: 82, Loss: 2.395
# Epoch: 0, Batch: 83, Loss: 1.805
# Epoch: 0, Batch: 84, Loss: 2.117
# Epoch: 0, Batch: 85, Loss: 2.453
# Epoch: 0, Batch: 86, Loss: 2.295
# Epoch: 0, Batch: 87, Loss: 1.597
# Epoch: 0, Batch: 88, Loss: 2.072
# Epoch: 0, Batch: 89, Loss: 1.416
# Epoch: 0, Batch: 90, Loss: 1.927
# Epoch: 0, Batch: 91, Loss: 1.678
# Epoch: 0, Batch: 92, Loss: 2.278
# Epoch: 0, Batch: 93, Loss: 1.999
# Epoch: 0, Batch: 94, Loss: 2.237
# Epoch: 0, Batch: 95, Loss: 2.214
# Epoch: 0, Batch: 96, Loss: 1.800
# Epoch: 0, Batch: 97, Loss: 2.127
# Epoch: 0, Batch: 98, Loss: 2.273
# Epoch: 0, Batch: 99, Loss: 2.116
# Epoch: 0, Batch: 100, Loss: 2.291
# Epoch: 0, Batch: 101, Loss: 2.226
# Epoch: 0, Batch: 102, Loss: 2.313
# Epoch: 0, Batch: 103, Loss: 2.241
# Epoch: 0, Batch: 104, Loss: 2.122
# Epoch: 0, Batch: 105, Loss: 1.918
# Epoch: 0, Batch: 106, Loss: 2.040
# Epoch: 0, Batch: 107, Loss: 2.073
# Epoch: 0, Batch: 108, Loss: 2.275
# Epoch: 0, Batch: 109, Loss: 1.944
# Epoch: 0, Batch: 110, Loss: 2.619
# Epoch: 0, Batch: 111, Loss: 1.685
# Epoch: 0, Batch: 112, Loss: 2.100
# Epoch: 0, Batch: 113, Loss: 1.960
# Epoch: 0, Batch: 114, Loss: 1.899
# Epoch: 0, Batch: 115, Loss: 1.940
# Epoch: 0, Batch: 116, Loss: 2.371
# Epoch: 0, Batch: 117, Loss: 2.299
# Epoch: 0, Batch: 118, Loss: 1.842
# Epoch: 0, Batch: 119, Loss: 1.854
# Epoch: 0, Batch: 120, Loss: 2.033
# Epoch: 0, Batch: 121, Loss: 2.445
# Epoch: 0, Batch: 122, Loss: 1.983
# Epoch: 0, Batch: 123, Loss: 1.767
# Epoch: 0, Batch: 124, Loss: 2.338
# Epoch: 0, Batch: 125, Loss: 1.945
# Epoch: 0, Batch: 126, Loss: 2.981
# Epoch: 0, Batch: 127, Loss: 2.114
# Epoch: 0, Batch: 128, Loss: 1.843
# Epoch: 0, Batch: 129, Loss: 2.595
# Epoch: 0, Batch: 130, Loss: 2.361
# Epoch: 0, Batch: 131, Loss: 2.336
# Epoch: 0, Batch: 132, Loss: 2.090
# Epoch: 0, Batch: 133, Loss: 1.897
# Epoch: 0, Batch: 134, Loss: 1.803
# Epoch: 0, Batch: 135, Loss: 2.406
# Epoch: 0, Batch: 136, Loss: 1.839
# Epoch: 0, Batch: 137, Loss: 2.158
# Epoch: 0, Batch: 138, Loss: 2.367
# Epoch: 0, Batch: 139, Loss: 2.136
# Epoch: 0, Batch: 140, Loss: 2.489
# Epoch: 0, Batch: 141, Loss: 1.681
# Epoch: 0, Batch: 142, Loss: 2.113
# Epoch: 0, Batch: 143, Loss: 1.887
# Epoch: 0, Batch: 144, Loss: 1.851
# Epoch: 0, Batch: 145, Loss: 1.989
# Epoch: 0, Batch: 146, Loss: 1.891
# Epoch: 0, Batch: 147, Loss: 2.313
# Epoch: 0, Batch: 148, Loss: 3.044
# Epoch: 0, Batch: 149, Loss: 2.062
# Epoch: 0, Batch: 150, Loss: 1.903
# Epoch: 0, Batch: 151, Loss: 2.262
# Epoch: 0, Batch: 152, Loss: 1.890
# Epoch: 0, Batch: 153, Loss: 1.813
# Epoch: 0, Batch: 154, Loss: 2.225
# Epoch: 0, Batch: 155, Loss: 1.969
# Epoch: 0, Batch: 156, Loss: 1.796
# Epoch: 0, Batch: 157, Loss: 1.728
# Epoch: 0, Batch: 158, Loss: 1.874
# Epoch: 0, Batch: 159, Loss: 2.709
# Epoch: 0, Batch: 160, Loss: 1.940
# Epoch: 0, Batch: 161, Loss: 1.829
# Epoch: 0, Batch: 162, Loss: 2.285
# Epoch: 0, Batch: 163, Loss: 2.112
# Epoch: 0, Batch: 164, Loss: 2.156
# Epoch: 0, Batch: 165, Loss: 2.131
# Epoch: 0, Batch: 166, Loss: 1.719
# Epoch: 0, Batch: 167, Loss: 1.946
# Epoch: 0, Batch: 168, Loss: 1.905
# Epoch: 0, Batch: 169, Loss: 2.103
# Epoch: 0, Batch: 170, Loss: 1.978
# Epoch: 0, Batch: 171, Loss: 2.103
# Epoch: 0, Batch: 172, Loss: 2.040
# Epoch: 0, Batch: 173, Loss: 1.773
# Epoch: 0, Batch: 174, Loss: 1.985
# Epoch: 0, Batch: 175, Loss: 2.108
# Epoch: 0, Batch: 176, Loss: 1.897
# Epoch: 0, Batch: 177, Loss: 2.563
# Epoch: 0, Batch: 178, Loss: 2.066
# Epoch: 0, Batch: 179, Loss: 1.876
# Epoch: 0, Batch: 180, Loss: 2.016
# Epoch: 0, Batch: 181, Loss: 1.988
# Epoch: 0, Batch: 182, Loss: 2.370
# Epoch: 0, Batch: 183, Loss: 2.525
# Epoch: 0, Batch: 184, Loss: 2.342
# Epoch: 0, Batch: 185, Loss: 2.069
# Epoch: 0, Batch: 186, Loss: 1.922
# Epoch: 0, Batch: 187, Loss: 2.390
# Epoch: 0, Batch: 188, Loss: 2.470
# Epoch: 0, Batch: 189, Loss: 2.143
# Epoch: 0, Batch: 190, Loss: 2.421
# Epoch: 0, Batch: 191, Loss: 2.243
# Epoch: 0, Batch: 192, Loss: 1.982
# Epoch: 0, Batch: 193, Loss: 1.982
# Epoch: 0, Batch: 194, Loss: 2.163
# Epoch: 0, Batch: 195, Loss: 1.864
# Epoch: 0, Batch: 196, Loss: 1.933
# Epoch: 0, Batch: 197, Loss: 1.993
# Epoch: 0, Batch: 198, Loss: 2.158
# Epoch: 0, Batch: 199, Loss: 2.209
# Epoch: 0, Batch: 200, Loss: 2.327
# Epoch: 0, Batch: 201, Loss: 2.270
# Epoch: 0, Batch: 202, Loss: 2.386
# Epoch: 0, Batch: 203, Loss: 2.128
# Epoch: 0, Batch: 204, Loss: 2.047
# Epoch: 0, Batch: 205, Loss: 1.940
# Epoch: 0, Batch: 206, Loss: 2.423
# Epoch: 0, Batch: 207, Loss: 2.794
# Epoch: 0, Batch: 208, Loss: 1.341
# Epoch: 0, Batch: 209, Loss: 2.388
# Epoch: 0, Batch: 210, Loss: 1.987
# Epoch: 0, Batch: 211, Loss: 2.086
# Epoch: 0, Batch: 212, Loss: 1.772
# Epoch: 0, Batch: 213, Loss: 1.816
# Epoch: 0, Batch: 214, Loss: 1.966
# Epoch: 0, Batch: 215, Loss: 2.043
# Epoch: 0, Batch: 216, Loss: 2.016
# Epoch: 0, Batch: 217, Loss: 2.575
# Epoch: 0, Batch: 218, Loss: 2.070
# Epoch: 0, Batch: 219, Loss: 2.012
# Epoch: 0, Batch: 220, Loss: 1.932
# Epoch: 0, Batch: 221, Loss: 1.859
# Epoch: 0, Batch: 222, Loss: 2.306
# Epoch: 0, Batch: 223, Loss: 2.021
# Epoch: 0, Batch: 224, Loss: 2.029
# Epoch: 0, Batch: 225, Loss: 2.239
# Epoch: 0, Batch: 226, Loss: 2.248
# Epoch: 0, Batch: 227, Loss: 2.346
# Epoch: 0, Batch: 228, Loss: 1.956
# Epoch: 0, Batch: 229, Loss: 2.288
# Epoch: 0, Batch: 230, Loss: 2.110
# Epoch: 0, Batch: 231, Loss: 2.205
# Epoch: 0, Batch: 232, Loss: 2.176
# Epoch: 0, Batch: 233, Loss: 2.598
# Epoch: 0, Batch: 234, Loss: 1.890
# Epoch: 0, Batch: 235, Loss: 1.372
# Epoch: 0, Batch: 236, Loss: 2.088
# Epoch: 0, Batch: 237, Loss: 2.258
# Epoch: 0, Batch: 238, Loss: 2.217
# Epoch: 0, Batch: 239, Loss: 1.660
# Epoch: 0, Batch: 240, Loss: 2.179
# Epoch: 0, Batch: 241, Loss: 2.068
# Epoch: 0, Batch: 242, Loss: 2.218
# Epoch: 0, Batch: 243, Loss: 1.939
# Epoch: 0, Batch: 244, Loss: 1.945
# Epoch: 0, Batch: 245, Loss: 2.265
# Epoch: 0, Batch: 246, Loss: 1.900
# Epoch: 0, Batch: 247, Loss: 2.378
# Epoch: 0, Batch: 248, Loss: 1.921
# Epoch: 0, Batch: 249, Loss: 2.073
# Epoch: 0, Batch: 250, Loss: 2.118
# Epoch: 0, Batch: 251, Loss: 1.842
# Epoch: 0, Batch: 252, Loss: 1.889
# Epoch: 0, Batch: 253, Loss: 2.130
# Epoch: 0, Batch: 254, Loss: 1.857
# Epoch: 0, Batch: 255, Loss: 1.920
# Epoch: 0, Batch: 256, Loss: 2.116
# Epoch: 0, Batch: 257, Loss: 2.240
# Epoch: 0, Batch: 258, Loss: 2.291
# Epoch: 0, Batch: 259, Loss: 2.293
# Epoch: 0, Batch: 260, Loss: 1.963
# Epoch: 0, Batch: 261, Loss: 2.261
# Epoch: 0, Batch: 262, Loss: 1.789
# Epoch: 0, Batch: 263, Loss: 1.831
# Epoch: 0, Batch: 264, Loss: 1.982
# Epoch: 0, Batch: 265, Loss: 2.104
# Epoch: 0, Batch: 266, Loss: 2.147
# Epoch: 0, Batch: 267, Loss: 1.977
# Epoch: 0, Batch: 268, Loss: 2.160
# Epoch: 0, Batch: 269, Loss: 1.630
# Epoch: 0, Batch: 270, Loss: 2.211
# Epoch: 0, Batch: 271, Loss: 1.970
# Epoch: 0, Batch: 272, Loss: 2.478
# Epoch: 0, Batch: 273, Loss: 2.328
# Epoch: 0, Batch: 274, Loss: 2.079
# Epoch: 0, Batch: 275, Loss: 2.314
# Epoch: 0, Batch: 276, Loss: 1.923
# Epoch: 0, Batch: 277, Loss: 2.059
# Epoch: 0, Batch: 278, Loss: 1.904
# Epoch: 0, Batch: 279, Loss: 1.959
# Epoch: 0, Batch: 280, Loss: 2.244
# Epoch: 0, Batch: 281, Loss: 1.456
# Epoch: 0, Batch: 282, Loss: 2.499
# Epoch: 0, Batch: 283, Loss: 2.513
# Epoch: 0, Batch: 284, Loss: 2.012
# Epoch: 0, Batch: 285, Loss: 2.229
# Epoch: 0, Batch: 286, Loss: 1.810
# Epoch: 0, Batch: 287, Loss: 1.828
# Epoch: 0, Batch: 288, Loss: 2.095
# Epoch: 0, Batch: 289, Loss: 2.200
# Epoch: 0, Batch: 290, Loss: 2.369
# Epoch: 0, Batch: 291, Loss: 1.566
# Epoch: 0, Batch: 292, Loss: 2.365
# Epoch: 0, Batch: 293, Loss: 1.905
# Epoch: 0, Batch: 294, Loss: 2.068
# Epoch: 0, Batch: 295, Loss: 1.992
# Epoch: 0, Batch: 296, Loss: 2.062
# Epoch: 0, Batch: 297, Loss: 1.819
# Epoch: 0, Batch: 298, Loss: 2.492
# Epoch: 0, Batch: 299, Loss: 1.916
# Epoch: 0, Batch: 300, Loss: 2.174
# Epoch: 0, Batch: 301, Loss: 2.078
# Epoch: 0, Batch: 302, Loss: 2.133
# Epoch: 0, Batch: 303, Loss: 1.778
# Epoch: 0, Batch: 304, Loss: 1.793
# Epoch: 0, Batch: 305, Loss: 2.159
# Epoch: 0, Batch: 306, Loss: 1.831
# Epoch: 0, Batch: 307, Loss: 2.021
# Epoch: 0, Batch: 308, Loss: 1.909
# Epoch: 0, Batch: 309, Loss: 2.065
# Epoch: 0, Batch: 310, Loss: 1.879
# Epoch: 0, Batch: 311, Loss: 1.941
# Epoch: 0, Batch: 312, Loss: 1.627
# Epoch: 0, Batch: 313, Loss: 2.375
# Epoch: 0, Batch: 314, Loss: 1.928
# Epoch: 0, Batch: 315, Loss: 1.967
# Epoch: 0, Batch: 316, Loss: 2.371
# Epoch: 0, Batch: 317, Loss: 2.281
# Epoch: 0, Batch: 318, Loss: 2.055
# Epoch: 0, Batch: 319, Loss: 1.948
# Epoch: 0, Batch: 320, Loss: 2.054
# Epoch: 0, Batch: 321, Loss: 1.753
# Epoch: 0, Batch: 322, Loss: 1.709
# Epoch: 0, Batch: 323, Loss: 2.058
# Epoch: 0, Batch: 324, Loss: 2.136
# Epoch: 0, Batch: 325, Loss: 1.798
# Epoch: 0, Batch: 326, Loss: 2.049
# Epoch: 0, Batch: 327, Loss: 2.186
# Epoch: 0, Batch: 328, Loss: 2.109
# Epoch: 0, Batch: 329, Loss: 1.990
# Epoch: 0, Batch: 330, Loss: 1.555
# Epoch: 0, Batch: 331, Loss: 2.196
# Epoch: 0, Batch: 332, Loss: 2.200
# Epoch: 0, Batch: 333, Loss: 1.994
# Epoch: 0, Batch: 334, Loss: 1.741
# Epoch: 0, Batch: 335, Loss: 1.541
# Epoch: 0, Batch: 336, Loss: 1.950
# Epoch: 0, Batch: 337, Loss: 2.127
# Epoch: 0, Batch: 338, Loss: 1.961
# Epoch: 0, Batch: 339, Loss: 1.971
# Epoch: 0, Batch: 340, Loss: 2.044
# Epoch: 0, Batch: 341, Loss: 2.135
# Epoch: 0, Batch: 342, Loss: 1.631
# Epoch: 0, Batch: 343, Loss: 1.941
# Epoch: 0, Batch: 344, Loss: 2.039
# Epoch: 0, Batch: 345, Loss: 2.155
# Epoch: 0, Batch: 346, Loss: 2.251
# Epoch: 0, Batch: 347, Loss: 1.886
# Epoch: 0, Batch: 348, Loss: 1.999
# Epoch: 0, Batch: 349, Loss: 1.645
# Epoch: 0, Batch: 350, Loss: 2.242
# Epoch: 0, Batch: 351, Loss: 1.805
# Epoch: 0, Batch: 352, Loss: 1.753
# Epoch: 0, Batch: 353, Loss: 2.616
# Epoch: 0, Batch: 354, Loss: 2.249
# Epoch: 0, Batch: 355, Loss: 1.955
# Epoch: 0, Batch: 356, Loss: 2.124
# Epoch: 0, Batch: 357, Loss: 1.979
# Epoch: 0, Batch: 358, Loss: 1.825
# Epoch: 0, Batch: 359, Loss: 2.418
# Epoch: 0, Batch: 360, Loss: 2.132
# Epoch: 0, Batch: 361, Loss: 2.000
# Epoch: 0, Batch: 362, Loss: 1.942
# Epoch: 0, Batch: 363, Loss: 1.988
# Epoch: 0, Batch: 364, Loss: 2.165
# Epoch: 0, Batch: 365, Loss: 2.097
# Epoch: 0, Batch: 366, Loss: 2.353
# Epoch: 0, Batch: 367, Loss: 2.316
# Epoch: 0, Batch: 368, Loss: 2.121
# Epoch: 0, Batch: 369, Loss: 1.921
# Epoch: 0, Batch: 370, Loss: 2.133
# Epoch: 0, Batch: 371, Loss: 2.094
# Epoch: 0, Batch: 372, Loss: 2.299
# Epoch: 0, Batch: 373, Loss: 1.965
# Epoch: 0, Batch: 374, Loss: 2.161
# Epoch: 0, Batch: 375, Loss: 2.148
# Epoch: 0, Batch: 376, Loss: 2.279
# Epoch: 0, Batch: 377, Loss: 1.719
# Epoch: 0, Batch: 378, Loss: 2.011
# Epoch: 0, Batch: 379, Loss: 2.089
# Epoch: 0, Batch: 380, Loss: 2.162
# Epoch: 0, Batch: 381, Loss: 2.238
# Epoch: 0, Batch: 382, Loss: 1.733
# Epoch: 0, Batch: 383, Loss: 1.944
# Epoch: 0, Batch: 384, Loss: 2.259
# Epoch: 0, Batch: 385, Loss: 2.097
# Epoch: 0, Batch: 386, Loss: 2.114
# Epoch: 0, Batch: 387, Loss: 1.862
# Epoch: 0, Batch: 388, Loss: 1.716
# Epoch: 0, Batch: 389, Loss: 1.910
# Epoch: 0, Batch: 390, Loss: 1.931
# Epoch: 0, Batch: 391, Loss: 2.139
# Epoch: 0, Batch: 392, Loss: 2.018
# Epoch: 0, Batch: 393, Loss: 2.624
# Epoch: 0, Batch: 394, Loss: 1.974
# Epoch: 0, Batch: 395, Loss: 2.312
# Epoch: 0, Batch: 396, Loss: 2.374
# Epoch: 0, Batch: 397, Loss: 1.849
# Epoch: 0, Batch: 398, Loss: 2.073
# Epoch: 0, Batch: 399, Loss: 2.579
# Epoch: 0, Batch: 400, Loss: 1.918
# Epoch: 0, Batch: 401, Loss: 1.685
# Epoch: 0, Batch: 402, Loss: 2.420
# Epoch: 0, Batch: 403, Loss: 2.196
# Epoch: 0, Batch: 404, Loss: 2.042
# Epoch: 0, Batch: 405, Loss: 2.272
# Epoch: 0, Batch: 406, Loss: 2.101
# Epoch: 0, Batch: 407, Loss: 2.248
# Epoch: 0, Batch: 408, Loss: 2.308
# Epoch: 0, Batch: 409, Loss: 2.349
# Epoch: 0, Batch: 410, Loss: 1.683
# Epoch: 0, Batch: 411, Loss: 1.855
# Epoch: 0, Batch: 412, Loss: 2.211
# Epoch: 0, Batch: 413, Loss: 1.911
# Epoch: 0, Batch: 414, Loss: 1.535
# Epoch: 0, Batch: 415, Loss: 1.886
# Epoch: 0, Batch: 416, Loss: 1.967
# Epoch: 0, Batch: 417, Loss: 1.853
# Epoch: 0, Batch: 418, Loss: 1.916
# Epoch: 0, Batch: 419, Loss: 2.309
# Epoch: 0, Batch: 420, Loss: 1.950
# Epoch: 0, Batch: 421, Loss: 2.090
# Epoch: 0, Batch: 422, Loss: 2.115
# Epoch: 0, Batch: 423, Loss: 2.142
# Epoch: 0, Batch: 424, Loss: 1.694
# Epoch: 0, Batch: 425, Loss: 1.612
# Epoch: 0, Batch: 426, Loss: 2.294
# Epoch: 0, Batch: 427, Loss: 2.133
# Epoch: 0, Batch: 428, Loss: 1.984
# Epoch: 0, Batch: 429, Loss: 2.042
# Epoch: 0, Batch: 430, Loss: 1.745
# Epoch: 0, Batch: 431, Loss: 2.414
# Epoch: 0, Batch: 432, Loss: 2.176
# Epoch: 0, Batch: 433, Loss: 2.394
# Epoch: 0, Batch: 434, Loss: 1.970
# Epoch: 0, Batch: 435, Loss: 1.850
# Epoch: 0, Batch: 436, Loss: 2.154
# Epoch: 0, Batch: 437, Loss: 2.353
# Epoch: 0, Batch: 438, Loss: 2.011
# Epoch: 0, Batch: 439, Loss: 2.087
# Epoch: 0, Batch: 440, Loss: 1.909
# Epoch: 0, Batch: 441, Loss: 2.584
# Epoch: 0, Batch: 442, Loss: 1.773
# Epoch: 0, Batch: 443, Loss: 2.176
# Epoch: 0, Batch: 444, Loss: 1.983
# Epoch: 0, Batch: 445, Loss: 2.050
# Epoch: 0, Batch: 446, Loss: 2.389
# Epoch: 0, Batch: 447, Loss: 2.443
# Epoch: 0, Batch: 448, Loss: 2.411
# Epoch: 0, Batch: 449, Loss: 1.861
# Epoch: 0, Batch: 450, Loss: 2.342
# Epoch: 0, Batch: 451, Loss: 2.496
# Epoch: 0, Batch: 452, Loss: 2.330
# Epoch: 0, Batch: 453, Loss: 2.518
# Epoch: 0, Batch: 454, Loss: 1.854
# Epoch: 0, Batch: 455, Loss: 1.754
# Epoch: 0, Batch: 456, Loss: 1.868
# Epoch: 0, Batch: 457, Loss: 1.651
# Epoch: 0, Batch: 458, Loss: 1.858
# Epoch: 0, Batch: 459, Loss: 2.254
# Epoch: 0, Batch: 460, Loss: 2.148
# Epoch: 0, Batch: 461, Loss: 2.109
# Epoch: 0, Batch: 462, Loss: 2.183
# Epoch: 0, Batch: 463, Loss: 1.926
# Epoch: 0, Batch: 464, Loss: 1.922
# Epoch: 0, Batch: 465, Loss: 1.659
# Epoch: 0, Batch: 466, Loss: 1.805
# Epoch: 0, Batch: 467, Loss: 1.854
# Epoch: 0, Batch: 468, Loss: 2.252
# Epoch: 0, Batch: 469, Loss: 1.910
# Epoch: 0, Batch: 470, Loss: 2.383
# Epoch: 0, Batch: 471, Loss: 1.768
# Epoch: 0, Batch: 472, Loss: 2.128
# Epoch: 0, Batch: 473, Loss: 2.437
# Epoch: 0, Batch: 474, Loss: 2.084
# Epoch: 0, Batch: 475, Loss: 1.848
# Epoch: 0, Batch: 476, Loss: 1.610
# Epoch: 0, Batch: 477, Loss: 2.231
# Epoch: 0, Batch: 478, Loss: 2.208
# Epoch: 0, Batch: 479, Loss: 1.922
# Epoch: 0, Batch: 480, Loss: 2.062
# Epoch: 0, Batch: 481, Loss: 2.127
# Epoch: 0, Batch: 482, Loss: 2.077
# Epoch: 0, Batch: 483, Loss: 2.482
# Epoch: 0, Batch: 484, Loss: 1.988
# Epoch: 0, Batch: 485, Loss: 1.891
# Epoch: 0, Batch: 486, Loss: 2.147
# Epoch: 0, Batch: 487, Loss: 1.723
# Epoch: 0, Batch: 488, Loss: 1.897
# Epoch: 0, Batch: 489, Loss: 1.699
# Epoch: 0, Batch: 490, Loss: 2.200
# Epoch: 0, Batch: 491, Loss: 2.242
# Epoch: 0, Batch: 492, Loss: 2.391
# Epoch: 0, Batch: 493, Loss: 1.857
# Epoch: 0, Batch: 494, Loss: 2.116
# Epoch: 0, Batch: 495, Loss: 2.312
# Epoch: 0, Batch: 496, Loss: 2.066
# Epoch: 0, Batch: 497, Loss: 2.108
# Epoch: 0, Batch: 498, Loss: 1.887
# Epoch: 0, Batch: 499, Loss: 1.676
# Epoch: 0, Batch: 500, Loss: 1.922
# Epoch: 0, Batch: 501, Loss: 1.818
# Epoch: 0, Batch: 502, Loss: 2.448
# Epoch: 0, Batch: 503, Loss: 2.423
# Epoch: 0, Batch: 504, Loss: 2.487
# Epoch: 0, Batch: 505, Loss: 1.809
# Epoch: 0, Batch: 506, Loss: 1.880
# Epoch: 0, Batch: 507, Loss: 2.332
# Epoch: 0, Batch: 508, Loss: 2.081
# Epoch: 0, Batch: 509, Loss: 2.365
# Epoch: 0, Batch: 510, Loss: 1.975
# Epoch: 0, Batch: 511, Loss: 2.013
# Epoch: 0, Batch: 512, Loss: 2.111
# Epoch: 0, Batch: 513, Loss: 1.807
# Epoch: 0, Batch: 514, Loss: 1.946
# Epoch: 0, Batch: 515, Loss: 1.858
# Epoch: 0, Batch: 516, Loss: 1.650
# Epoch: 0, Batch: 517, Loss: 1.905
# Epoch: 0, Batch: 518, Loss: 2.036
# Epoch: 0, Batch: 519, Loss: 1.713
# Epoch: 0, Batch: 520, Loss: 2.112
# Epoch: 0, Batch: 521, Loss: 2.089
# Epoch: 0, Batch: 522, Loss: 2.198
# Epoch: 0, Batch: 523, Loss: 1.939
# Epoch: 0, Batch: 524, Loss: 2.238
# Epoch: 0, Batch: 525, Loss: 1.813
# Epoch: 0, Batch: 526, Loss: 2.080
# Epoch: 0, Batch: 527, Loss: 2.274
# Epoch: 0, Batch: 528, Loss: 1.734
# Epoch: 0, Batch: 529, Loss: 1.622
# Epoch: 0, Batch: 530, Loss: 2.347
# Epoch: 0, Batch: 531, Loss: 2.207
# Epoch: 0, Batch: 532, Loss: 2.031
# Epoch: 0, Batch: 533, Loss: 2.117
# Epoch: 0, Batch: 534, Loss: 2.582
# Epoch: 0, Batch: 535, Loss: 1.784
# Epoch: 0, Batch: 536, Loss: 1.965
# Epoch: 0, Batch: 537, Loss: 1.649
# Epoch: 0, Batch: 538, Loss: 2.257
# Epoch: 0, Batch: 539, Loss: 1.796
# Epoch: 0, Batch: 540, Loss: 1.943
# Epoch: 0, Batch: 541, Loss: 1.939
# Epoch: 0, Batch: 542, Loss: 2.106
# Epoch: 0, Batch: 543, Loss: 1.892
# Epoch: 0, Batch: 544, Loss: 1.989
# Epoch: 0, Batch: 545, Loss: 2.167
# Epoch: 0, Batch: 546, Loss: 2.359
# Epoch: 0, Batch: 547, Loss: 1.734
# Epoch: 0, Batch: 548, Loss: 2.267
# Epoch: 0, Batch: 549, Loss: 1.714
# Epoch: 0, Batch: 550, Loss: 2.294
# Epoch: 0, Batch: 551, Loss: 2.049
# Epoch: 0, Batch: 552, Loss: 2.030
# Epoch: 0, Batch: 553, Loss: 2.068
# Epoch: 0, Batch: 554, Loss: 1.797
# Epoch: 0, Batch: 555, Loss: 2.316
# Epoch: 0, Batch: 556, Loss: 2.062
# Epoch: 0, Batch: 557, Loss: 1.713
# Epoch: 0, Batch: 558, Loss: 1.855
# Epoch: 0, Batch: 559, Loss: 2.243
# Epoch: 0, Batch: 560, Loss: 1.882
# Epoch: 0, Batch: 561, Loss: 1.670
# Epoch: 0, Batch: 562, Loss: 2.340
# Epoch: 0, Batch: 563, Loss: 2.180
# Epoch: 0, Batch: 564, Loss: 2.376
# Epoch: 0, Batch: 565, Loss: 1.871
# Epoch: 0, Batch: 566, Loss: 2.046
# Epoch: 0, Batch: 567, Loss: 2.331
# Epoch: 0, Batch: 568, Loss: 2.388
# Epoch: 0, Batch: 569, Loss: 2.092
# Epoch: 0, Batch: 570, Loss: 2.055
# Epoch: 0, Batch: 571, Loss: 1.700
# Epoch: 0, Batch: 572, Loss: 2.039
# Epoch: 0, Batch: 573, Loss: 1.968
# Epoch: 0, Batch: 574, Loss: 2.420
# Epoch: 0, Batch: 575, Loss: 1.913
# Epoch: 0, Batch: 576, Loss: 2.448
# Epoch: 0, Batch: 577, Loss: 1.580
# Epoch: 0, Batch: 578, Loss: 2.142
# Epoch: 0, Batch: 579, Loss: 1.693
# Epoch: 0, Batch: 580, Loss: 2.303
# Epoch: 0, Batch: 581, Loss: 2.321
# Epoch: 0, Batch: 582, Loss: 2.044
# Epoch: 0, Batch: 583, Loss: 1.889
# Epoch: 0, Batch: 584, Loss: 2.227
# Epoch: 0, Batch: 585, Loss: 1.958
# Epoch: 0, Batch: 586, Loss: 1.842
# Epoch: 0, Batch: 587, Loss: 2.416
# Epoch: 0, Batch: 588, Loss: 2.211
# Epoch: 0, Batch: 589, Loss: 2.111
# Epoch: 0, Batch: 590, Loss: 1.903
# Epoch: 0, Batch: 591, Loss: 1.971
# Epoch: 0, Batch: 592, Loss: 2.285
# Epoch: 0, Batch: 593, Loss: 2.204
# Epoch: 0, Batch: 594, Loss: 2.237
# Epoch: 0, Batch: 595, Loss: 1.803
# Epoch: 0, Batch: 596, Loss: 1.740
# Epoch: 0, Batch: 597, Loss: 1.773
# Epoch: 0, Batch: 598, Loss: 1.715
# Epoch: 0, Batch: 599, Loss: 1.815
# Epoch: 0, Batch: 600, Loss: 1.823
# Epoch: 0, Batch: 601, Loss: 2.798
# Epoch: 0, Batch: 602, Loss: 2.050
# Epoch: 0, Batch: 603, Loss: 2.193
# Epoch: 0, Batch: 604, Loss: 1.688
# Epoch: 0, Batch: 605, Loss: 2.415
# Epoch: 0, Batch: 606, Loss: 2.691
# Epoch: 0, Batch: 607, Loss: 2.091
# Epoch: 0, Batch: 608, Loss: 2.237
# Epoch: 0, Batch: 609, Loss: 2.302
# Epoch: 0, Batch: 610, Loss: 2.296
# Epoch: 0, Batch: 611, Loss: 2.135
# Epoch: 0, Batch: 612, Loss: 2.072
# Epoch: 0, Batch: 613, Loss: 2.132
# Epoch: 0, Batch: 614, Loss: 2.326
# Epoch: 0, Batch: 615, Loss: 2.091
# Epoch: 0, Batch: 616, Loss: 2.373
# Epoch: 0, Batch: 617, Loss: 1.964
# Epoch: 0, Batch: 618, Loss: 1.920
# Epoch: 0, Batch: 619, Loss: 2.013
# Epoch: 0, Batch: 620, Loss: 2.009
# Epoch: 0, Batch: 621, Loss: 1.950
# Epoch: 0, Batch: 622, Loss: 2.322
# Epoch: 0, Batch: 623, Loss: 2.006
# Epoch: 0, Batch: 624, Loss: 1.601
# Epoch: 0, Batch: 625, Loss: 1.957
# Epoch: 0, Batch: 626, Loss: 2.450
# Epoch: 0, Batch: 627, Loss: 1.988
# Epoch: 0, Batch: 628, Loss: 2.335
# Epoch: 0, Batch: 629, Loss: 1.898
# Epoch: 0, Batch: 630, Loss: 2.222
# Epoch: 0, Batch: 631, Loss: 2.039
# Epoch: 0, Batch: 632, Loss: 2.364
# Epoch: 0, Batch: 633, Loss: 1.926
# Epoch: 0, Batch: 634, Loss: 2.540
# Epoch: 0, Batch: 635, Loss: 2.279
# Epoch: 0, Batch: 636, Loss: 2.377
# Epoch: 0, Batch: 637, Loss: 1.542
# Epoch: 0, Batch: 638, Loss: 1.821
# Epoch: 0, Batch: 639, Loss: 2.604
# Epoch: 0, Batch: 640, Loss: 1.993
# Epoch: 0, Batch: 641, Loss: 2.076
# Epoch: 0, Batch: 642, Loss: 2.533
# Epoch: 0, Batch: 643, Loss: 1.756
# Epoch: 0, Batch: 644, Loss: 2.058
# Epoch: 0, Batch: 645, Loss: 2.266
# Epoch: 0, Batch: 646, Loss: 2.102
# Epoch: 0, Batch: 647, Loss: 1.987
# Epoch: 0, Batch: 648, Loss: 2.229
# Epoch: 0, Batch: 649, Loss: 2.011
# Epoch: 0, Batch: 650, Loss: 2.175
# Epoch: 0, Batch: 651, Loss: 2.262
# Epoch: 0, Batch: 652, Loss: 2.159
# Epoch: 0, Batch: 653, Loss: 2.156
# Epoch: 0, Batch: 654, Loss: 2.179
# Epoch: 0, Batch: 655, Loss: 1.593
# Epoch: 0, Batch: 656, Loss: 1.991
# Epoch: 0, Batch: 657, Loss: 1.863
# Epoch: 0, Batch: 658, Loss: 1.770
# Epoch: 0, Batch: 659, Loss: 1.860
# Epoch: 0, Batch: 660, Loss: 2.201
# Epoch: 0, Batch: 661, Loss: 1.929
# Epoch: 0, Batch: 662, Loss: 1.945
# Epoch: 0, Batch: 663, Loss: 1.834
# Epoch: 0, Batch: 664, Loss: 2.363
# Epoch: 0, Batch: 665, Loss: 2.378
# Epoch: 0, Batch: 666, Loss: 1.931
# Epoch: 0, Batch: 667, Loss: 2.150
# Epoch: 0, Batch: 668, Loss: 2.187
# Epoch: 0, Batch: 669, Loss: 1.903
# Epoch: 0, Batch: 670, Loss: 1.820
# Epoch: 0, Batch: 671, Loss: 2.146
# Epoch: 0, Batch: 672, Loss: 2.237
# Epoch: 0, Batch: 673, Loss: 1.713
# Epoch: 0, Batch: 674, Loss: 1.816
# Epoch: 0, Batch: 675, Loss: 1.993
# Epoch: 0, Batch: 676, Loss: 2.235
# Epoch: 0, Batch: 677, Loss: 2.004
# Epoch: 0, Batch: 678, Loss: 2.271
# Epoch: 0, Batch: 679, Loss: 2.097
# Epoch: 0, Batch: 680, Loss: 1.892
# Epoch: 0, Batch: 681, Loss: 1.981
# Epoch: 0, Batch: 682, Loss: 1.513
# Epoch: 0, Batch: 683, Loss: 2.390
# Epoch: 0, Batch: 684, Loss: 2.437
# Epoch: 0, Batch: 685, Loss: 1.644
# Epoch: 0, Batch: 686, Loss: 2.528
# Epoch: 0, Batch: 687, Loss: 2.079
# Epoch: 0, Batch: 688, Loss: 1.845
# Epoch: 0, Batch: 689, Loss: 1.838
# Epoch: 0, Batch: 690, Loss: 2.163
# Epoch: 0, Batch: 691, Loss: 2.276
# Epoch: 0, Batch: 692, Loss: 2.179
# Epoch: 0, Batch: 693, Loss: 2.005
# Epoch: 0, Batch: 694, Loss: 2.145
# Epoch: 0, Batch: 695, Loss: 2.248
# Epoch: 0, Batch: 696, Loss: 1.659
# Epoch: 0, Batch: 697, Loss: 2.165
# Epoch: 0, Batch: 698, Loss: 1.935
# Epoch: 0, Batch: 699, Loss: 1.935
# Epoch: 0, Batch: 700, Loss: 1.947
# Epoch: 0, Batch: 701, Loss: 1.874
# Epoch: 0, Batch: 702, Loss: 2.608
# Epoch: 0, Batch: 703, Loss: 2.068
# Epoch: 0, Batch: 704, Loss: 1.919
# Epoch: 0, Batch: 705, Loss: 1.616
# Epoch: 0, Batch: 706, Loss: 2.661
# Epoch: 0, Batch: 707, Loss: 2.242
# Epoch: 0, Batch: 708, Loss: 1.843
# Epoch: 0, Batch: 709, Loss: 2.313
# Epoch: 0, Batch: 710, Loss: 1.746
# Epoch: 0, Batch: 711, Loss: 2.196
# Epoch: 0, Batch: 712, Loss: 2.015
# Epoch: 0, Batch: 713, Loss: 2.039
# Epoch: 0, Batch: 714, Loss: 1.962
# Epoch: 0, Batch: 715, Loss: 1.898
# Epoch: 0, Batch: 716, Loss: 2.211
# Epoch: 0, Batch: 717, Loss: 2.061
# Epoch: 0, Batch: 718, Loss: 2.166
# Epoch: 0, Batch: 719, Loss: 1.962
# Epoch: 0, Batch: 720, Loss: 1.870
# Epoch: 0, Batch: 721, Loss: 2.360
# Epoch: 0, Batch: 722, Loss: 2.110
# Epoch: 0, Batch: 723, Loss: 2.057
# Epoch: 0, Batch: 724, Loss: 1.997
# Epoch: 0, Batch: 725, Loss: 1.945
# Epoch: 0, Batch: 726, Loss: 1.994
# Epoch: 0, Batch: 727, Loss: 2.026
# Epoch: 0, Batch: 728, Loss: 2.303
# Epoch: 0, Batch: 729, Loss: 2.243
# Epoch: 0, Batch: 730, Loss: 2.083
# Epoch: 0, Batch: 731, Loss: 1.973
# Epoch: 0, Batch: 732, Loss: 1.676
# Epoch: 0, Batch: 733, Loss: 2.028
# Epoch: 0, Batch: 734, Loss: 2.422
# Epoch: 0, Batch: 735, Loss: 1.622
# Epoch: 0, Batch: 736, Loss: 2.193
# Epoch: 0, Batch: 737, Loss: 1.912
# Epoch: 0, Batch: 738, Loss: 1.794
# Epoch: 0, Batch: 739, Loss: 1.814
# Epoch: 0, Batch: 740, Loss: 2.122
# Epoch: 0, Batch: 741, Loss: 1.948
# Epoch: 0, Batch: 742, Loss: 1.756
# Epoch: 0, Batch: 743, Loss: 2.606
# Epoch: 0, Batch: 744, Loss: 1.740
# Epoch: 0, Batch: 745, Loss: 2.077
# Epoch: 0, Batch: 746, Loss: 2.287
# Epoch: 0, Batch: 747, Loss: 2.231
# Epoch: 0, Batch: 748, Loss: 2.384
# Epoch: 0, Batch: 749, Loss: 2.227
# Epoch: 0, Batch: 750, Loss: 2.438
# Epoch: 0, Batch: 751, Loss: 1.735
# Epoch: 0, Batch: 752, Loss: 2.421
# Epoch: 0, Batch: 753, Loss: 1.941
# Epoch: 0, Batch: 754, Loss: 1.836
# Epoch: 0, Batch: 755, Loss: 1.966
# Epoch: 0, Batch: 756, Loss: 1.853
# Epoch: 0, Batch: 757, Loss: 1.685
# Epoch: 0, Batch: 758, Loss: 1.997
# Epoch: 0, Batch: 759, Loss: 1.931
# Epoch: 0, Batch: 760, Loss: 2.317
# Epoch: 0, Batch: 761, Loss: 1.920
# Epoch: 0, Batch: 762, Loss: 1.631
# Epoch: 0, Batch: 763, Loss: 1.969
# Epoch: 0, Batch: 764, Loss: 2.188
# Epoch: 0, Batch: 765, Loss: 2.119
# Epoch: 0, Batch: 766, Loss: 2.171
# Epoch: 0, Batch: 767, Loss: 2.188
# Epoch: 0, Batch: 768, Loss: 2.315
# Epoch: 0, Batch: 769, Loss: 2.789
# Epoch: 0, Batch: 770, Loss: 1.822
# Epoch: 0, Batch: 771, Loss: 2.467
# Epoch: 0, Batch: 772, Loss: 1.862
# Epoch: 0, Batch: 773, Loss: 1.902
# Epoch: 0, Batch: 774, Loss: 1.942
# Epoch: 0, Batch: 775, Loss: 2.077
# Epoch: 0, Batch: 776, Loss: 1.922
# Epoch: 0, Batch: 777, Loss: 2.050
# Epoch: 0, Batch: 778, Loss: 2.172
# Epoch: 0, Batch: 779, Loss: 1.744
# Epoch: 0, Batch: 780, Loss: 1.836
# Epoch: 0, Batch: 781, Loss: 2.083
# Epoch: 0, Batch: 782, Loss: 1.918
# Epoch: 0, Batch: 783, Loss: 2.125
# Epoch: 0, Batch: 784, Loss: 1.925
# Epoch: 0, Batch: 785, Loss: 1.942
# Epoch: 0, Batch: 786, Loss: 2.282
# Epoch: 0, Batch: 787, Loss: 2.253
# Epoch: 0, Batch: 788, Loss: 1.720
# Epoch: 0, Batch: 789, Loss: 1.589
# Epoch: 0, Batch: 790, Loss: 1.734
# Epoch: 0, Batch: 791, Loss: 1.864
# Epoch: 0, Batch: 792, Loss: 2.185
# Epoch: 0, Batch: 793, Loss: 2.040
# Epoch: 0, Batch: 794, Loss: 1.714
# Epoch: 0, Batch: 795, Loss: 2.077
# Epoch: 0, Batch: 796, Loss: 1.923
# Epoch: 0, Batch: 797, Loss: 2.170
# Epoch: 0, Batch: 798, Loss: 2.248
# Epoch: 0, Batch: 799, Loss: 2.230
# Epoch: 0, Batch: 800, Loss: 2.328
# Epoch: 0, Batch: 801, Loss: 2.405
# Epoch: 0, Batch: 802, Loss: 2.141
# Epoch: 0, Batch: 803, Loss: 1.867
# Epoch: 0, Batch: 804, Loss: 2.056
# Epoch: 0, Batch: 805, Loss: 2.083
# Epoch: 0, Batch: 806, Loss: 1.867
# Epoch: 0, Batch: 807, Loss: 2.005
# Epoch: 0, Batch: 808, Loss: 2.268
# Epoch: 0, Batch: 809, Loss: 2.388
# Epoch: 0, Batch: 810, Loss: 1.699
# Epoch: 0, Batch: 811, Loss: 1.961
# Epoch: 0, Batch: 812, Loss: 2.562
# Epoch: 0, Batch: 813, Loss: 1.986
# Epoch: 0, Batch: 814, Loss: 2.183
# Epoch: 0, Batch: 815, Loss: 2.024
# Epoch: 0, Batch: 816, Loss: 2.321
# Epoch: 0, Batch: 817, Loss: 2.202
# Epoch: 0, Batch: 818, Loss: 1.910
# Epoch: 0, Batch: 819, Loss: 2.353
# Epoch: 0, Batch: 820, Loss: 1.819
# Epoch: 0, Batch: 821, Loss: 2.167
# Epoch: 0, Batch: 822, Loss: 1.867
# Epoch: 0, Batch: 823, Loss: 1.972
# Epoch: 0, Batch: 824, Loss: 1.597
# Epoch: 0, Batch: 825, Loss: 2.061
# Epoch: 0, Batch: 826, Loss: 1.485
# Epoch: 0, Batch: 827, Loss: 1.884
# Epoch: 0, Batch: 828, Loss: 2.340
# Epoch: 0, Batch: 829, Loss: 1.718
# Epoch: 0, Batch: 830, Loss: 1.976
# Epoch: 0, Batch: 831, Loss: 2.174
# Epoch: 0, Batch: 832, Loss: 1.894
# Epoch: 0, Batch: 833, Loss: 2.007
# Epoch: 0, Batch: 834, Loss: 2.264
# Epoch: 0, Batch: 835, Loss: 2.184
# Epoch: 0, Batch: 836, Loss: 1.752
# Epoch: 0, Batch: 837, Loss: 1.711
# Epoch: 0, Batch: 838, Loss: 2.090
# Epoch: 0, Batch: 839, Loss: 2.521
# Epoch: 0, Batch: 840, Loss: 2.541
# Epoch: 0, Batch: 841, Loss: 2.214
# Epoch: 0, Batch: 842, Loss: 2.158
# Epoch: 0, Batch: 843, Loss: 2.751
# Epoch: 0, Batch: 844, Loss: 2.160
# Epoch: 0, Batch: 845, Loss: 1.617
# Epoch: 0, Batch: 846, Loss: 1.851
# Epoch: 0, Batch: 847, Loss: 1.703
# Epoch: 0, Batch: 848, Loss: 1.858
# Epoch: 0, Batch: 849, Loss: 1.876
# Epoch: 0, Batch: 850, Loss: 2.023
# Epoch: 0, Batch: 851, Loss: 1.891
# Epoch: 0, Batch: 852, Loss: 1.711
# Epoch: 0, Batch: 853, Loss: 2.610
# Epoch: 0, Batch: 854, Loss: 1.934
# Epoch: 0, Batch: 855, Loss: 2.005
# Epoch: 0, Batch: 856, Loss: 2.231
# Epoch: 0, Batch: 857, Loss: 1.814
# Epoch: 0, Batch: 858, Loss: 2.046
# Epoch: 0, Batch: 859, Loss: 2.149
# Epoch: 0, Batch: 860, Loss: 2.097
# Epoch: 0, Batch: 861, Loss: 1.810
# Epoch: 0, Batch: 862, Loss: 1.802
# Epoch: 0, Batch: 863, Loss: 2.290
# Epoch: 0, Batch: 864, Loss: 1.757
# Epoch: 0, Batch: 865, Loss: 2.227
# Epoch: 0, Batch: 866, Loss: 1.791
# Epoch: 0, Batch: 867, Loss: 2.234
# Epoch: 0, Batch: 868, Loss: 1.748
# Epoch: 0, Batch: 869, Loss: 2.057
# Epoch: 0, Batch: 870, Loss: 2.113
# Epoch: 0, Batch: 871, Loss: 2.059
# Epoch: 0, Batch: 872, Loss: 2.027
# Epoch: 0, Batch: 873, Loss: 2.177
# Epoch: 0, Batch: 874, Loss: 2.011
# Epoch: 0, Batch: 875, Loss: 2.288
# Epoch: 0, Batch: 876, Loss: 2.015
# Epoch: 0, Batch: 877, Loss: 1.597
# Epoch: 0, Batch: 878, Loss: 1.966
# Epoch: 0, Batch: 879, Loss: 2.200
# Epoch: 0, Batch: 880, Loss: 2.004
# Epoch: 0, Batch: 881, Loss: 2.339
# Epoch: 0, Batch: 882, Loss: 2.227
# Epoch: 0, Batch: 883, Loss: 1.957
# Epoch: 0, Batch: 884, Loss: 1.894
# Epoch: 0, Batch: 885, Loss: 2.135
# Epoch: 0, Batch: 886, Loss: 2.034
# Epoch: 0, Batch: 887, Loss: 2.441
# Epoch: 0, Batch: 888, Loss: 1.954
# Epoch: 0, Batch: 889, Loss: 1.992
# Epoch: 0, Batch: 890, Loss: 2.174
# Epoch: 0, Batch: 891, Loss: 2.178
# Epoch: 0, Batch: 892, Loss: 2.073
# Epoch: 0, Batch: 893, Loss: 1.815
# Epoch: 0, Batch: 894, Loss: 2.331
# Epoch: 0, Batch: 895, Loss: 2.365
# Epoch: 0, Batch: 896, Loss: 2.002
# Epoch: 0, Batch: 897, Loss: 2.656
# Epoch: 0, Batch: 898, Loss: 2.482
# Epoch: 0, Batch: 899, Loss: 1.772
# Epoch: 0, Batch: 900, Loss: 1.857
# Epoch: 0, Batch: 901, Loss: 2.068
# Epoch: 0, Batch: 902, Loss: 2.003
# Epoch: 0, Batch: 903, Loss: 2.423
# Epoch: 0, Batch: 904, Loss: 2.416
# Epoch: 0, Batch: 905, Loss: 2.115
# Epoch: 0, Batch: 906, Loss: 2.348
# Epoch: 0, Batch: 907, Loss: 2.235
# Epoch: 0, Batch: 908, Loss: 2.086
# Epoch: 0, Batch: 909, Loss: 2.445
# Epoch: 0, Batch: 910, Loss: 1.789
# Epoch: 0, Batch: 911, Loss: 2.071
# Epoch: 0, Batch: 912, Loss: 1.553
# Epoch: 0, Batch: 913, Loss: 2.158
# Epoch: 0, Batch: 914, Loss: 1.944
# Epoch: 0, Batch: 915, Loss: 2.173
# Epoch: 0, Batch: 916, Loss: 2.339
# Epoch: 0, Batch: 917, Loss: 2.234
# Epoch: 0, Batch: 918, Loss: 1.843
# Epoch: 0, Batch: 919, Loss: 1.838
# Epoch: 0, Batch: 920, Loss: 1.680
# Epoch: 0, Batch: 921, Loss: 2.327
# Epoch: 0, Batch: 922, Loss: 2.113
# Epoch: 0, Batch: 923, Loss: 2.248
# Epoch: 0, Batch: 924, Loss: 1.870
# Epoch: 0, Batch: 925, Loss: 1.759
# Epoch: 0, Batch: 926, Loss: 2.007
# Epoch: 0, Batch: 927, Loss: 2.040
# Epoch: 0, Batch: 928, Loss: 1.962
# Epoch: 0, Batch: 929, Loss: 2.247
# Epoch: 0, Batch: 930, Loss: 2.270
# Epoch: 0, Batch: 931, Loss: 1.736
# Epoch: 0, Batch: 932, Loss: 2.044
# Epoch: 0, Batch: 933, Loss: 1.995
# Epoch: 0, Batch: 934, Loss: 2.064
# Epoch: 0, Batch: 935, Loss: 2.287
# Epoch: 0, Batch: 936, Loss: 2.017
# Epoch: 0, Batch: 937, Loss: 2.057
# Epoch: 0, Batch: 938, Loss: 2.079
# Epoch: 0, Batch: 939, Loss: 2.130
# Epoch: 0, Batch: 940, Loss: 1.782
# Epoch: 0, Batch: 941, Loss: 2.244
# Epoch: 0, Batch: 942, Loss: 1.893
# Epoch: 0, Batch: 943, Loss: 2.215
# Epoch: 0, Batch: 944, Loss: 2.102
# Epoch: 0, Batch: 945, Loss: 1.373
# Epoch: 0, Batch: 946, Loss: 2.631
# Epoch: 0, Batch: 947, Loss: 2.219
# Epoch: 0, Batch: 948, Loss: 1.992
# Epoch: 0, Batch: 949, Loss: 1.904
# Epoch: 0, Batch: 950, Loss: 1.779
# Epoch: 0, Batch: 951, Loss: 2.187
# Epoch: 0, Batch: 952, Loss: 2.160
# Epoch: 0, Batch: 953, Loss: 1.934
# Epoch: 0, Batch: 954, Loss: 1.890
# Epoch: 0, Batch: 955, Loss: 2.129
# Epoch: 0, Batch: 956, Loss: 2.159
# Epoch: 0, Batch: 957, Loss: 2.235
# Epoch: 0, Batch: 958, Loss: 2.118
# Epoch: 0, Batch: 959, Loss: 1.677
# Epoch: 0, Batch: 960, Loss: 1.674
# Epoch: 0, Batch: 961, Loss: 1.797
# Epoch: 0, Batch: 962, Loss: 2.261
# Epoch: 0, Batch: 963, Loss: 2.194
# Epoch: 0, Batch: 964, Loss: 2.020
# Epoch: 0, Batch: 965, Loss: 1.805
# Epoch: 0, Batch: 966, Loss: 2.087
# Epoch: 0, Batch: 967, Loss: 2.311
# Epoch: 0, Batch: 968, Loss: 1.713
# Epoch: 0, Batch: 969, Loss: 2.306
# Epoch: 0, Batch: 970, Loss: 1.782
# Epoch: 0, Batch: 971, Loss: 1.849
# Epoch: 0, Batch: 972, Loss: 2.392
# Epoch: 0, Batch: 973, Loss: 2.120
# Epoch: 0, Batch: 974, Loss: 1.894
# Epoch: 0, Batch: 975, Loss: 1.902
# Epoch: 0, Batch: 976, Loss: 1.992
# Epoch: 0, Batch: 977, Loss: 2.054
# Epoch: 0, Batch: 978, Loss: 2.166
# Epoch: 0, Batch: 979, Loss: 2.189
# Epoch: 0, Batch: 980, Loss: 1.901
# Epoch: 0, Batch: 981, Loss: 2.600
# Epoch: 0, Batch: 982, Loss: 2.346
# Epoch: 0, Batch: 983, Loss: 1.725
# Epoch: 0, Batch: 984, Loss: 1.770
# Epoch: 0, Batch: 985, Loss: 2.330
# Epoch: 0, Batch: 986, Loss: 2.463
# Epoch: 0, Batch: 987, Loss: 2.269
# Epoch: 0, Batch: 988, Loss: 2.396
# Epoch: 0, Batch: 989, Loss: 2.546
# Epoch: 0, Batch: 990, Loss: 2.276
# Epoch: 0, Batch: 991, Loss: 1.796
# Epoch: 0, Batch: 992, Loss: 2.003
# Epoch: 0, Batch: 993, Loss: 2.294
# Epoch: 0, Batch: 994, Loss: 2.413
# Epoch: 0, Batch: 995, Loss: 1.951
# Epoch: 0, Batch: 996, Loss: 1.964
# Epoch: 0, Batch: 997, Loss: 1.774
# Epoch: 0, Batch: 998, Loss: 1.553
# Epoch: 0, Batch: 999, Loss: 2.336
# Epoch: 0, Batch: 1000, Loss: 2.216
# Epoch: 0, Batch: 1001, Loss: 2.090
# Epoch: 0, Batch: 1002, Loss: 1.939
# Epoch: 0, Batch: 1003, Loss: 2.143
# Epoch: 0, Batch: 1004, Loss: 2.204
# Epoch: 0, Batch: 1005, Loss: 2.330
# Epoch: 0, Batch: 1006, Loss: 2.351
# Epoch: 0, Batch: 1007, Loss: 1.476
# Epoch: 0, Batch: 1008, Loss: 1.859
# Epoch: 0, Batch: 1009, Loss: 1.704
# Epoch: 0, Batch: 1010, Loss: 2.049
# Epoch: 0, Batch: 1011, Loss: 1.986
# Epoch: 0, Batch: 1012, Loss: 2.079
# Epoch: 0, Batch: 1013, Loss: 1.877
# Epoch: 0, Batch: 1014, Loss: 2.160
# Epoch: 0, Batch: 1015, Loss: 2.376
# Epoch: 0, Batch: 1016, Loss: 2.726
# Epoch: 0, Batch: 1017, Loss: 2.185
# Epoch: 0, Batch: 1018, Loss: 2.508
# Epoch: 0, Batch: 1019, Loss: 1.975
# Epoch: 0, Batch: 1020, Loss: 2.014
# Epoch: 0, Batch: 1021, Loss: 2.210
# Epoch: 0, Batch: 1022, Loss: 2.367
# Epoch: 0, Batch: 1023, Loss: 2.121
# Epoch: 0, Batch: 1024, Loss: 1.900
# Epoch: 0, Batch: 1025, Loss: 2.332
# Epoch: 0, Batch: 1026, Loss: 2.208
# Epoch: 0, Batch: 1027, Loss: 2.102
# Epoch: 0, Batch: 1028, Loss: 2.200
# Epoch: 0, Batch: 1029, Loss: 1.819
# Epoch: 0, Batch: 1030, Loss: 1.883
# Epoch: 0, Batch: 1031, Loss: 2.056
# Epoch: 0, Batch: 1032, Loss: 2.349
# Epoch: 0, Batch: 1033, Loss: 1.963
# Epoch: 0, Batch: 1034, Loss: 1.979
# Epoch: 0, Batch: 1035, Loss: 2.748
# Epoch: 0, Batch: 1036, Loss: 1.961
# Epoch: 0, Batch: 1037, Loss: 2.635
# Epoch: 0, Batch: 1038, Loss: 1.956
# Epoch: 0, Batch: 1039, Loss: 2.083
# Epoch: 0, Batch: 1040, Loss: 2.202
# Epoch: 0, Batch: 1041, Loss: 2.056
# Epoch: 0, Batch: 1042, Loss: 2.252
# Epoch: 0, Batch: 1043, Loss: 2.473
# Epoch: 0, Batch: 1044, Loss: 2.322
# Epoch: 0, Batch: 1045, Loss: 1.504
# Epoch: 0, Batch: 1046, Loss: 1.821
# Epoch: 0, Batch: 1047, Loss: 1.918
# Epoch: 0, Batch: 1048, Loss: 2.317
# Epoch: 0, Batch: 1049, Loss: 2.132
# Epoch: 0, Batch: 1050, Loss: 1.979
# Epoch: 0, Batch: 1051, Loss: 2.630
# Epoch: 0, Batch: 1052, Loss: 1.906
# Epoch: 0, Batch: 1053, Loss: 2.048
# Epoch: 0, Batch: 1054, Loss: 2.041
# Epoch: 0, Batch: 1055, Loss: 1.945
# Epoch: 0, Batch: 1056, Loss: 2.205
# Epoch: 0, Batch: 1057, Loss: 2.152
# Epoch: 0, Batch: 1058, Loss: 2.134
# Epoch: 0, Batch: 1059, Loss: 2.178
# Epoch: 0, Batch: 1060, Loss: 2.076
# Epoch: 0, Batch: 1061, Loss: 1.838
# Epoch: 0, Batch: 1062, Loss: 1.415
# Epoch: 0, Batch: 1063, Loss: 1.523
# Epoch: 0, Batch: 1064, Loss: 1.968
# Epoch: 0, Batch: 1065, Loss: 2.502
# Epoch: 0, Batch: 1066, Loss: 1.912
# Epoch: 0, Batch: 1067, Loss: 2.404
# Epoch: 0, Batch: 1068, Loss: 2.293
# Epoch: 0, Batch: 1069, Loss: 2.028
# Epoch: 0, Batch: 1070, Loss: 2.241
# Epoch: 0, Batch: 1071, Loss: 1.654
# Epoch: 0, Batch: 1072, Loss: 2.570
# Epoch: 0, Batch: 1073, Loss: 2.428
# Epoch: 0, Batch: 1074, Loss: 2.124
# Epoch: 0, Batch: 1075, Loss: 1.805
# Epoch: 0, Batch: 1076, Loss: 2.237
# Epoch: 0, Batch: 1077, Loss: 2.280
# Epoch: 0, Batch: 1078, Loss: 2.332
# Epoch: 0, Batch: 1079, Loss: 2.442
# Epoch: 0, Batch: 1080, Loss: 2.192
# Epoch: 0, Batch: 1081, Loss: 1.848
# Epoch: 0, Batch: 1082, Loss: 2.015
# Epoch: 0, Batch: 1083, Loss: 1.879
# Epoch: 0, Batch: 1084, Loss: 1.927
# Epoch: 0, Batch: 1085, Loss: 2.232
# Epoch: 0, Batch: 1086, Loss: 2.127
# Epoch: 0, Batch: 1087, Loss: 1.991
# Epoch: 0, Batch: 1088, Loss: 2.041
# Epoch: 0, Batch: 1089, Loss: 2.313
# Epoch: 0, Batch: 1090, Loss: 2.195
# Epoch: 0, Batch: 1091, Loss: 2.234
# Epoch: 0, Batch: 1092, Loss: 1.926
# Epoch: 0, Batch: 1093, Loss: 2.309
# Epoch: 0, Batch: 1094, Loss: 1.966
# Epoch: 0, Batch: 1095, Loss: 2.062
# Epoch: 0, Batch: 1096, Loss: 2.351
# Epoch: 0, Batch: 1097, Loss: 2.535
# Epoch: 0, Batch: 1098, Loss: 1.847
# Epoch: 0, Batch: 1099, Loss: 2.058
# Epoch: 0, Batch: 1100, Loss: 1.509
# Epoch: 0, Batch: 1101, Loss: 2.431
# Epoch: 0, Batch: 1102, Loss: 2.464
# Epoch: 0, Batch: 1103, Loss: 2.278
# Epoch: 0, Batch: 1104, Loss: 2.111
# Epoch: 0, Batch: 1105, Loss: 2.391
# Epoch: 0, Batch: 1106, Loss: 2.036
# Epoch: 0, Batch: 1107, Loss: 1.972
# Epoch: 0, Batch: 1108, Loss: 2.141
# Epoch: 0, Batch: 1109, Loss: 1.515
# Epoch: 0, Batch: 1110, Loss: 2.433
# Epoch: 0, Batch: 1111, Loss: 1.991
# Epoch: 0, Batch: 1112, Loss: 2.320
# Epoch: 0, Batch: 1113, Loss: 2.130
# Epoch: 0, Batch: 1114, Loss: 2.313
# Epoch: 0, Batch: 1115, Loss: 2.217
# Epoch: 0, Batch: 1116, Loss: 2.153
# Epoch: 0, Batch: 1117, Loss: 2.028
# Epoch: 0, Batch: 1118, Loss: 2.174
# Epoch: 0, Batch: 1119, Loss: 1.746
# Epoch: 0, Batch: 1120, Loss: 2.130
# Epoch: 0, Batch: 1121, Loss: 2.247
# Epoch: 0, Batch: 1122, Loss: 2.086
# Epoch: 0, Batch: 1123, Loss: 2.133
# Epoch: 0, Batch: 1124, Loss: 2.522
# Epoch: 0, Batch: 1125, Loss: 2.002
# Epoch: 0, Batch: 1126, Loss: 2.069
# Epoch: 0, Batch: 1127, Loss: 2.125
# Epoch: 0, Batch: 1128, Loss: 2.408
# Epoch: 0, Batch: 1129, Loss: 2.384
# Epoch: 0, Batch: 1130, Loss: 1.897
# Epoch: 0, Batch: 1131, Loss: 2.156
# Epoch: 0, Batch: 1132, Loss: 2.492
# Epoch: 0, Batch: 1133, Loss: 2.098
# Epoch: 0, Batch: 1134, Loss: 2.419
# Epoch: 0, Batch: 1135, Loss: 2.201
# Epoch: 0, Batch: 1136, Loss: 1.881
# Epoch: 0, Batch: 1137, Loss: 1.818
# Epoch: 0, Batch: 1138, Loss: 1.916
# Epoch: 0, Batch: 1139, Loss: 2.195
# Epoch: 0, Batch: 1140, Loss: 1.888
# Epoch: 0, Batch: 1141, Loss: 2.481
# Epoch: 0, Batch: 1142, Loss: 1.779
# Epoch: 0, Batch: 1143, Loss: 2.248
# Epoch: 0, Batch: 1144, Loss: 1.771
# Epoch: 0, Batch: 1145, Loss: 2.209
# Epoch: 0, Batch: 1146, Loss: 1.700
# Epoch: 0, Batch: 1147, Loss: 2.246
# Epoch: 0, Batch: 1148, Loss: 1.946
# Epoch: 0, Batch: 1149, Loss: 2.249
# Epoch: 0, Batch: 1150, Loss: 2.186
# Epoch: 0, Batch: 1151, Loss: 2.101
# Epoch: 0, Batch: 1152, Loss: 2.208
# Epoch: 0, Batch: 1153, Loss: 2.053
# Epoch: 0, Batch: 1154, Loss: 1.938
# Epoch: 0, Batch: 1155, Loss: 1.857
# Epoch: 0, Batch: 1156, Loss: 2.045
# Epoch: 0, Batch: 1157, Loss: 2.462
# Epoch: 0, Batch: 1158, Loss: 2.313
# Epoch: 0, Batch: 1159, Loss: 1.893
# Epoch: 0, Batch: 1160, Loss: 2.674
# Epoch: 0, Batch: 1161, Loss: 1.637
# Epoch: 0, Batch: 1162, Loss: 2.317
# Epoch: 0, Batch: 1163, Loss: 1.783
# Epoch: 0, Batch: 1164, Loss: 1.979
# Epoch: 0, Batch: 1165, Loss: 1.827
# Epoch: 0, Batch: 1166, Loss: 2.400
# Epoch: 0, Batch: 1167, Loss: 1.950
# Epoch: 0, Batch: 1168, Loss: 2.178
# Epoch: 0, Batch: 1169, Loss: 2.745
# Epoch: 0, Batch: 1170, Loss: 1.910
# Epoch: 0, Batch: 1171, Loss: 2.251
# Epoch: 0, Batch: 1172, Loss: 2.173
# Epoch: 0, Batch: 1173, Loss: 2.039
# Epoch: 0, Batch: 1174, Loss: 1.873
# Epoch: 0, Batch: 1175, Loss: 2.053
# Epoch: 0, Batch: 1176, Loss: 2.142
# Epoch: 0, Batch: 1177, Loss: 2.207
# Epoch: 0, Batch: 1178, Loss: 2.192
# Epoch: 0, Batch: 1179, Loss: 1.847
# Epoch: 0, Batch: 1180, Loss: 1.862
# Epoch: 0, Batch: 1181, Loss: 2.344
# Epoch: 0, Batch: 1182, Loss: 2.174
# Epoch: 0, Batch: 1183, Loss: 1.687
# Epoch: 0, Batch: 1184, Loss: 2.072
# Epoch: 0, Batch: 1185, Loss: 2.160
# Epoch: 0, Batch: 1186, Loss: 1.755
# Epoch: 0, Batch: 1187, Loss: 2.203
# Epoch: 0, Batch: 1188, Loss: 2.291
# Epoch: 0, Batch: 1189, Loss: 1.807
# Epoch: 0, Batch: 1190, Loss: 1.979
# Epoch: 0, Batch: 1191, Loss: 2.087
# Epoch: 0, Batch: 1192, Loss: 1.698
# Epoch: 0, Batch: 1193, Loss: 1.808
# Epoch: 0, Batch: 1194, Loss: 2.419
# Epoch: 0, Batch: 1195, Loss: 1.724
# Epoch: 0, Batch: 1196, Loss: 1.945
# Epoch: 0, Batch: 1197, Loss: 1.895
# Epoch: 0, Batch: 1198, Loss: 2.309
# Epoch: 0, Batch: 1199, Loss: 1.995
# Epoch: 0, Batch: 1200, Loss: 2.213
# Epoch: 0, Batch: 1201, Loss: 1.453
# Epoch: 0, Batch: 1202, Loss: 2.234
# Epoch: 0, Batch: 1203, Loss: 2.132
# Epoch: 0, Batch: 1204, Loss: 1.611
# Epoch: 0, Batch: 1205, Loss: 2.003
# Epoch: 0, Batch: 1206, Loss: 2.528
# Epoch: 0, Batch: 1207, Loss: 2.148
# Epoch: 0, Batch: 1208, Loss: 1.906
# Epoch: 0, Batch: 1209, Loss: 2.228
# Epoch: 0, Batch: 1210, Loss: 2.119
# Epoch: 0, Batch: 1211, Loss: 2.412
# Epoch: 0, Batch: 1212, Loss: 1.983
# Epoch: 0, Batch: 1213, Loss: 1.960
# Epoch: 0, Batch: 1214, Loss: 2.221
# Epoch: 0, Batch: 1215, Loss: 2.344
# Epoch: 0, Batch: 1216, Loss: 1.680
# Epoch: 0, Batch: 1217, Loss: 2.215
# Epoch: 0, Batch: 1218, Loss: 2.010
# Epoch: 0, Batch: 1219, Loss: 2.340
# Epoch: 0, Batch: 1220, Loss: 2.281
# Epoch: 0, Batch: 1221, Loss: 1.933
# Epoch: 0, Batch: 1222, Loss: 2.049
# Epoch: 0, Batch: 1223, Loss: 1.949
# Epoch: 0, Batch: 1224, Loss: 2.019
# Epoch: 0, Batch: 1225, Loss: 2.134
# Epoch: 0, Batch: 1226, Loss: 2.095
# Epoch: 0, Batch: 1227, Loss: 2.106
# Epoch: 0, Batch: 1228, Loss: 2.005
# Epoch: 0, Batch: 1229, Loss: 1.866
# Epoch: 0, Batch: 1230, Loss: 2.142
# Epoch: 0, Batch: 1231, Loss: 2.207
# Epoch: 0, Batch: 1232, Loss: 2.389
# Epoch: 0, Batch: 1233, Loss: 2.034
# Epoch: 0, Batch: 1234, Loss: 1.916
# Epoch: 0, Batch: 1235, Loss: 2.069
# Epoch: 0, Batch: 1236, Loss: 1.934
# Epoch: 0, Batch: 1237, Loss: 2.498
# Epoch: 0, Batch: 1238, Loss: 2.200
# Epoch: 0, Batch: 1239, Loss: 2.114
# Epoch: 0, Batch: 1240, Loss: 2.193
# Epoch: 0, Batch: 1241, Loss: 2.577
# Epoch: 0, Batch: 1242, Loss: 2.295
# Epoch: 0, Batch: 1243, Loss: 1.835
# Epoch: 0, Batch: 1244, Loss: 2.350
# Epoch: 0, Batch: 1245, Loss: 1.807
# Epoch: 0, Batch: 1246, Loss: 2.677
# Epoch: 0, Batch: 1247, Loss: 1.657
# Epoch: 0, Batch: 1248, Loss: 2.040
# Epoch: 0, Batch: 1249, Loss: 1.565
# Epoch: 0, Batch: 1250, Loss: 2.099
# Epoch: 0, Batch: 1251, Loss: 1.935
# Epoch: 0, Batch: 1252, Loss: 2.291
# Epoch: 0, Batch: 1253, Loss: 1.796
# Epoch: 0, Batch: 1254, Loss: 1.987
# Epoch: 0, Batch: 1255, Loss: 1.849
# Epoch: 0, Batch: 1256, Loss: 2.464
# Epoch: 0, Batch: 1257, Loss: 2.034
# Epoch: 0, Batch: 1258, Loss: 2.037
# Epoch: 0, Batch: 1259, Loss: 2.050
# Epoch: 0, Batch: 1260, Loss: 1.865
# Epoch: 0, Batch: 1261, Loss: 1.953
# Epoch: 0, Batch: 1262, Loss: 2.182
# Epoch: 0, Batch: 1263, Loss: 2.615
# Epoch: 0, Batch: 1264, Loss: 2.434
# Epoch: 0, Batch: 1265, Loss: 2.098
# Epoch: 0, Batch: 1266, Loss: 1.800
# Epoch: 0, Batch: 1267, Loss: 2.001
# Epoch: 0, Batch: 1268, Loss: 1.923
# Epoch: 0, Batch: 1269, Loss: 1.918
# Epoch: 0, Batch: 1270, Loss: 2.012
# Epoch: 0, Batch: 1271, Loss: 1.828
# Epoch: 0, Batch: 1272, Loss: 2.560
# Epoch: 0, Batch: 1273, Loss: 2.295
# Epoch: 0, Batch: 1274, Loss: 1.957
# Epoch: 0, Batch: 1275, Loss: 2.062
# Epoch: 0, Batch: 1276, Loss: 2.245
# Epoch: 0, Batch: 1277, Loss: 1.708
# Epoch: 0, Batch: 1278, Loss: 2.057
# Epoch: 0, Batch: 1279, Loss: 2.065
# Epoch: 0, Batch: 1280, Loss: 2.050
# Epoch: 0, Batch: 1281, Loss: 2.044
# Epoch: 0, Batch: 1282, Loss: 2.240
# Epoch: 0, Batch: 1283, Loss: 2.481
# Epoch: 0, Batch: 1284, Loss: 2.345
# Epoch: 0, Batch: 1285, Loss: 1.659
# Epoch: 0, Batch: 1286, Loss: 2.056
# Epoch: 0, Batch: 1287, Loss: 2.122
# Epoch: 0, Batch: 1288, Loss: 2.386
# Epoch: 0, Batch: 1289, Loss: 1.811
# Epoch: 0, Batch: 1290, Loss: 2.070
# Epoch: 0, Batch: 1291, Loss: 1.794
# Epoch: 0, Batch: 1292, Loss: 1.701
# Epoch: 0, Batch: 1293, Loss: 2.179
# Epoch: 0, Batch: 1294, Loss: 2.140
# Epoch: 0, Batch: 1295, Loss: 2.506
# Epoch: 0, Batch: 1296, Loss: 1.827
# Epoch: 0, Batch: 1297, Loss: 2.099
# Epoch: 0, Batch: 1298, Loss: 2.289
# Epoch: 0, Batch: 1299, Loss: 1.906
# Epoch: 0, Batch: 1300, Loss: 2.124
# Epoch: 0, Batch: 1301, Loss: 2.033
# Epoch: 0, Batch: 1302, Loss: 1.756
# Epoch: 0, Batch: 1303, Loss: 1.736
# Epoch: 0, Batch: 1304, Loss: 2.146
# Epoch: 0, Batch: 1305, Loss: 2.048
# Epoch: 0, Batch: 1306, Loss: 2.583
# Epoch: 0, Batch: 1307, Loss: 2.074
# Epoch: 0, Batch: 1308, Loss: 1.930
# Epoch: 0, Batch: 1309, Loss: 1.933
# Epoch: 0, Batch: 1310, Loss: 1.778
# Epoch: 0, Batch: 1311, Loss: 2.148
# Epoch: 0, Batch: 1312, Loss: 2.008
# Epoch: 0, Batch: 1313, Loss: 2.161
# Epoch: 0, Batch: 1314, Loss: 2.192
# Epoch: 0, Batch: 1315, Loss: 2.266
# Epoch: 0, Batch: 1316, Loss: 1.828
# Epoch: 0, Batch: 1317, Loss: 2.263
# Epoch: 0, Batch: 1318, Loss: 2.513
# Epoch: 0, Batch: 1319, Loss: 1.629
# Epoch: 0, Batch: 1320, Loss: 1.957
# Epoch: 0, Batch: 1321, Loss: 1.899
# Epoch: 0, Batch: 1322, Loss: 2.051
# Epoch: 0, Batch: 1323, Loss: 2.229
# Epoch: 0, Batch: 1324, Loss: 1.834
# Epoch: 0, Batch: 1325, Loss: 1.890
# Epoch: 0, Batch: 1326, Loss: 2.642
# Epoch: 0, Batch: 1327, Loss: 2.226
# Epoch: 0, Batch: 1328, Loss: 2.484
# Epoch: 0, Batch: 1329, Loss: 2.196
# Epoch: 0, Batch: 1330, Loss: 1.708
# Epoch: 0, Batch: 1331, Loss: 1.701
# Epoch: 0, Batch: 1332, Loss: 1.732
# Epoch: 0, Batch: 1333, Loss: 2.314
# Epoch: 0, Batch: 1334, Loss: 2.148
# Epoch: 0, Batch: 1335, Loss: 1.849
# Epoch: 0, Batch: 1336, Loss: 2.431
# Epoch: 0, Batch: 1337, Loss: 2.419
# Epoch: 0, Batch: 1338, Loss: 2.306
# Epoch: 0, Batch: 1339, Loss: 1.789
# Epoch: 0, Batch: 1340, Loss: 2.382
# Epoch: 0, Batch: 1341, Loss: 2.744
# Epoch: 0, Batch: 1342, Loss: 1.857
# Epoch: 0, Batch: 1343, Loss: 2.226
# Epoch: 0, Batch: 1344, Loss: 2.079
# Epoch: 0, Batch: 1345, Loss: 2.290
# Epoch: 0, Batch: 1346, Loss: 2.278
# Epoch: 0, Batch: 1347, Loss: 2.015
# Epoch: 0, Batch: 1348, Loss: 2.263
# Epoch: 0, Batch: 1349, Loss: 2.263
# Epoch: 0, Batch: 1350, Loss: 1.434
# Epoch: 0, Batch: 1351, Loss: 2.506
# Epoch: 0, Batch: 1352, Loss: 2.373
# Epoch: 0, Batch: 1353, Loss: 1.722
# Epoch: 0, Batch: 1354, Loss: 2.292
# Epoch: 0, Batch: 1355, Loss: 2.012
# Epoch: 0, Batch: 1356, Loss: 2.072
# Epoch: 0, Batch: 1357, Loss: 2.096
# Epoch: 0, Batch: 1358, Loss: 1.932
# Epoch: 0, Batch: 1359, Loss: 2.338
# Epoch: 0, Batch: 1360, Loss: 2.032
# Epoch: 0, Batch: 1361, Loss: 1.743
# Epoch: 0, Batch: 1362, Loss: 2.024
# Epoch: 0, Batch: 1363, Loss: 2.256
# Epoch: 0, Batch: 1364, Loss: 2.332
# Epoch: 0, Batch: 1365, Loss: 2.289
# Epoch: 0, Batch: 1366, Loss: 1.944
# Epoch: 0, Batch: 1367, Loss: 1.987
# Epoch: 0, Batch: 1368, Loss: 2.080
# Epoch: 0, Batch: 1369, Loss: 2.276
# Epoch: 0, Batch: 1370, Loss: 1.703
# Epoch: 0, Batch: 1371, Loss: 1.878
# Epoch: 0, Batch: 1372, Loss: 2.401
# Epoch: 0, Batch: 1373, Loss: 1.764
# Epoch: 0, Batch: 1374, Loss: 1.930
# Epoch: 0, Batch: 1375, Loss: 1.991
# Epoch: 0, Batch: 1376, Loss: 2.236
# Epoch: 0, Batch: 1377, Loss: 2.631
# Epoch: 0, Batch: 1378, Loss: 1.976
# Epoch: 0, Batch: 1379, Loss: 1.906
# Epoch: 0, Batch: 1380, Loss: 2.554
# Epoch: 0, Batch: 1381, Loss: 2.104
# Epoch: 0, Batch: 1382, Loss: 2.107
# Epoch: 0, Batch: 1383, Loss: 2.557
# Epoch: 0, Batch: 1384, Loss: 1.912
# Epoch: 0, Batch: 1385, Loss: 2.133
# Epoch: 0, Batch: 1386, Loss: 2.124
# Epoch: 0, Batch: 1387, Loss: 2.198
# Epoch: 0, Batch: 1388, Loss: 1.667
# Epoch: 0, Batch: 1389, Loss: 2.519
# Epoch: 0, Batch: 1390, Loss: 2.330
# Epoch: 0, Batch: 1391, Loss: 2.096
# Epoch: 0, Batch: 1392, Loss: 2.260
# Epoch: 0, Batch: 1393, Loss: 2.121
# Epoch: 0, Batch: 1394, Loss: 2.097
# Epoch: 0, Batch: 1395, Loss: 1.960
# Epoch: 0, Batch: 1396, Loss: 2.000
# Epoch: 0, Batch: 1397, Loss: 1.807
# Epoch: 0, Batch: 1398, Loss: 2.166
# Epoch: 0, Batch: 1399, Loss: 2.101
# Epoch: 0, Batch: 1400, Loss: 2.511
# Epoch: 0, Batch: 1401, Loss: 2.181
# ...
# Epoch: 0, Batch: 27441, Loss: 1.996
# Epoch: 0, Batch: 27442, Loss: 1.836
# Epoch: 0, Batch: 27443, Loss: 1.971
# Epoch: 0, Batch: 27444, Loss: 2.044
# Epoch: 0, Batch: 27445, Loss: 1.835
# Epoch: 0, Batch: 27446, Loss: 2.148
# Epoch: 0, Batch: 27447, Loss: 2.191
# Epoch: 0, Batch: 27448, Loss: 1.779
# Epoch: 0, Batch: 27449, Loss: 2.446
# Epoch: 0, Batch: 27450, Loss: 2.531
# Epoch: 0, Batch: 27451, Loss: 1.966
# Epoch: 0, Batch: 27452, Loss: 2.230
# Epoch: 0, Batch: 27453, Loss: 2.165
# Epoch: 0, Batch: 27454, Loss: 1.679
# Epoch: 0, Batch: 27455, Loss: 1.988
# Epoch: 0, Batch: 27456, Loss: 1.845
# Epoch: 0, Batch: 27457, Loss: 1.613
# Epoch: 0, Batch: 27458, Loss: 2.207
# Epoch: 0, Batch: 27459, Loss: 1.995
# Epoch: 0, Batch: 27460, Loss: 1.952
# Epoch: 0, Batch: 27461, Loss: 2.271
# Epoch: 0, Batch: 27462, Loss: 1.970
# Epoch: 0, Batch: 27463, Loss: 2.014
# Epoch: 0, Batch: 27464, Loss: 1.701
# Epoch: 0, Batch: 27465, Loss: 2.490
# Epoch: 0, Batch: 27466, Loss: 2.350
# Epoch: 0, Batch: 27467, Loss: 1.811
# Epoch: 0, Batch: 27468, Loss: 2.083
# Epoch: 0, Batch: 27469, Loss: 1.791
# Epoch: 0, Batch: 27470, Loss: 2.063
# Epoch: 0, Batch: 27471, Loss: 2.066
# Epoch: 0, Batch: 27472, Loss: 2.259
# Epoch: 0, Batch: 27473, Loss: 2.013
# Epoch: 0, Batch: 27474, Loss: 2.190
# Epoch: 0, Batch: 27475, Loss: 2.211
# Epoch: 0, Batch: 27476, Loss: 2.144
# Epoch: 0, Batch: 27477, Loss: 1.805
# Epoch: 0, Batch: 27478, Loss: 2.212
# Epoch: 0, Batch: 27479, Loss: 1.853
# Epoch: 0, Batch: 27480, Loss: 2.065
# Epoch: 0, Batch: 27481, Loss: 1.845
# Epoch: 0, Batch: 27482, Loss: 2.009
# Epoch: 0, Batch: 27483, Loss: 1.881
# Epoch: 0, Batch: 27484, Loss: 1.940
# Epoch: 0, Batch: 27485, Loss: 2.024
# Epoch: 0, Batch: 27486, Loss: 2.108
# Epoch: 0, Batch: 27487, Loss: 2.342
# Epoch: 0, Batch: 27488, Loss: 1.697
# Epoch: 0, Batch: 27489, Loss: 2.262
# Epoch: 0, Batch: 27490, Loss: 1.903
# Epoch: 0, Batch: 27491, Loss: 2.178
# Epoch: 0, Batch: 27492, Loss: 1.977
# Epoch: 0, Batch: 27493, Loss: 2.065
# Epoch: 0, Batch: 27494, Loss: 2.481
# Epoch: 0, Batch: 27495, Loss: 1.840
# Epoch: 0, Batch: 27496, Loss: 2.410
# Epoch: 0, Batch: 27497, Loss: 2.423
# Epoch: 0, Batch: 27498, Loss: 2.102
# Epoch: 0, Batch: 27499, Loss: 2.198
# Epoch: 0, Batch: 27500, Loss: 2.134
# Epoch: 0, Batch: 27501, Loss: 1.840
# Epoch: 0, Batch: 27502, Loss: 1.938
# Epoch: 0, Batch: 27503, Loss: 1.859
# Epoch: 0, Batch: 27504, Loss: 1.947
# Epoch: 0, Batch: 27505, Loss: 2.199
# Epoch: 0, Batch: 27506, Loss: 1.659
# Epoch: 0, Batch: 27507, Loss: 2.269
# Epoch: 0, Batch: 27508, Loss: 2.334
# Epoch: 0, Batch: 27509, Loss: 2.283
# Epoch: 0, Batch: 27510, Loss: 2.217
# Epoch: 0, Batch: 27511, Loss: 2.124
# Epoch: 0, Batch: 27512, Loss: 2.313
# Epoch: 0, Batch: 27513, Loss: 1.910
# Epoch: 0, Batch: 27514, Loss: 2.388
# Epoch: 0, Batch: 27515, Loss: 2.137
# Epoch: 0, Batch: 27516, Loss: 2.134
# Epoch: 0, Batch: 27517, Loss: 1.896
# Epoch: 0, Batch: 27518, Loss: 2.390
# Epoch: 0, Batch: 27519, Loss: 1.574
# Epoch: 0, Batch: 27520, Loss: 2.266
# Epoch: 0, Batch: 27521, Loss: 2.382
# Epoch: 0, Batch: 27522, Loss: 2.285
# Epoch: 0, Batch: 27523, Loss: 2.096
# Epoch: 0, Batch: 27524, Loss: 2.169
# Epoch: 0, Batch: 27525, Loss: 2.309
# Epoch: 0, Batch: 27526, Loss: 2.108
# Epoch: 0, Batch: 27527, Loss: 1.720
# Epoch: 0, Batch: 27528, Loss: 2.339
# Epoch: 0, Batch: 27529, Loss: 2.038
# Epoch: 0, Batch: 27530, Loss: 2.708
# Epoch: 0, Batch: 27531, Loss: 2.139
# Epoch: 0, Batch: 27532, Loss: 2.232
# Epoch: 0, Batch: 27533, Loss: 2.097
# Epoch: 0, Batch: 27534, Loss: 2.011
# Epoch: 0, Batch: 27535, Loss: 1.988
# Epoch: 0, Batch: 27536, Loss: 1.934
# Epoch: 0, Batch: 27537, Loss: 1.712
# Epoch: 0, Batch: 27538, Loss: 2.017
# Epoch: 0, Batch: 27539, Loss: 2.037
# Epoch: 0, Batch: 27540, Loss: 1.676
# Epoch: 0, Batch: 27541, Loss: 2.185
# Epoch: 0, Batch: 27542, Loss: 1.658
# Epoch: 0, Batch: 27543, Loss: 1.849
# Epoch: 0, Batch: 27544, Loss: 2.337
# Epoch: 0, Batch: 27545, Loss: 2.365
# Epoch: 0, Batch: 27546, Loss: 1.570
# Epoch: 0, Batch: 27547, Loss: 1.888
# Epoch: 0, Batch: 27548, Loss: 1.787
# Epoch: 0, Batch: 27549, Loss: 2.118
# Epoch: 0, Batch: 27550, Loss: 2.346
# Epoch: 0, Batch: 27551, Loss: 2.127
# Epoch: 0, Batch: 27552, Loss: 2.270
# Epoch: 0, Batch: 27553, Loss: 2.166
# Epoch: 0, Batch: 27554, Loss: 2.640
# Epoch: 0, Batch: 27555, Loss: 2.209
# Epoch: 0, Batch: 27556, Loss: 1.966
# Epoch: 0, Batch: 27557, Loss: 2.299
# Epoch: 0, Batch: 27558, Loss: 2.139
# Epoch: 0, Batch: 27559, Loss: 2.009
# Epoch: 0, Batch: 27560, Loss: 2.346
# Epoch: 0, Batch: 27561, Loss: 1.994
# Epoch: 0, Batch: 27562, Loss: 2.106
# Epoch: 0, Batch: 27563, Loss: 2.229
# Epoch: 0, Batch: 27564, Loss: 2.380
# Epoch: 0, Batch: 27565, Loss: 2.194
# Epoch: 0, Batch: 27566, Loss: 2.246
# Epoch: 0, Batch: 27567, Loss: 1.784
# Epoch: 0, Batch: 27568, Loss: 2.073
# Epoch: 0, Batch: 27569, Loss: 2.339
# Epoch: 0, Batch: 27570, Loss: 1.981
# Epoch: 0, Batch: 27571, Loss: 1.971
# Epoch: 0, Batch: 27572, Loss: 2.117
# Epoch: 0, Batch: 27573, Loss: 2.544
# Epoch: 0, Batch: 27574, Loss: 2.379
# Epoch: 0, Batch: 27575, Loss: 2.561
# Epoch: 0, Batch: 27576, Loss: 1.773
# Epoch: 0, Batch: 27577, Loss: 1.820
# Epoch: 0, Batch: 27578, Loss: 2.062
# Epoch: 0, Batch: 27579, Loss: 2.288
# Epoch: 0, Batch: 27580, Loss: 1.917
# Epoch: 0, Batch: 27581, Loss: 2.535
# Epoch: 0, Batch: 27582, Loss: 2.225
# Epoch: 0, Batch: 27583, Loss: 2.067
# Epoch: 0, Batch: 27584, Loss: 2.443
# Epoch: 0, Batch: 27585, Loss: 2.120
# Epoch: 0, Batch: 27586, Loss: 2.186
# Epoch: 0, Batch: 27587, Loss: 1.656
# Epoch: 0, Batch: 27588, Loss: 1.956
# Epoch: 0, Batch: 27589, Loss: 1.909
# Epoch: 0, Batch: 27590, Loss: 2.332
# Epoch: 0, Batch: 27591, Loss: 2.509
# Epoch: 0, Batch: 27592, Loss: 2.375
# Epoch: 0, Batch: 27593, Loss: 1.908
# Epoch: 0, Batch: 27594, Loss: 1.925
# Epoch: 0, Batch: 27595, Loss: 2.346
# Epoch: 0, Batch: 27596, Loss: 2.218
# Epoch: 0, Batch: 27597, Loss: 1.899
# Epoch: 0, Batch: 27598, Loss: 2.380
# Epoch: 0, Batch: 27599, Loss: 1.937
# Epoch: 0, Batch: 27600, Loss: 2.207
# Epoch: 0, Batch: 27601, Loss: 2.151
# Epoch: 0, Batch: 27602, Loss: 1.870
# Epoch: 0, Batch: 27603, Loss: 2.208
# Epoch: 0, Batch: 27604, Loss: 1.884
# Epoch: 0, Batch: 27605, Loss: 1.635
# Epoch: 0, Batch: 27606, Loss: 2.334
# Epoch: 0, Batch: 27607, Loss: 2.328
# Epoch: 0, Batch: 27608, Loss: 2.075
# Epoch: 0, Batch: 27609, Loss: 2.012
# Epoch: 0, Batch: 27610, Loss: 1.640
# Epoch: 0, Batch: 27611, Loss: 1.736
# Epoch: 0, Batch: 27612, Loss: 2.795
# Epoch: 0, Batch: 27613, Loss: 2.176
# Epoch: 0, Batch: 27614, Loss: 1.703
# Epoch: 0, Batch: 27615, Loss: 2.247
# Epoch: 0, Batch: 27616, Loss: 2.446
# Epoch: 0, Batch: 27617, Loss: 1.966
# Epoch: 0, Batch: 27618, Loss: 2.124
# Epoch: 0, Batch: 27619, Loss: 1.751
# Epoch: 0, Batch: 27620, Loss: 2.406
# Epoch: 0, Batch: 27621, Loss: 1.904
# Epoch: 0, Batch: 27622, Loss: 1.759
# Epoch: 0, Batch: 27623, Loss: 1.937
# Epoch: 0, Batch: 27624, Loss: 1.877
# Epoch: 0, Batch: 27625, Loss: 1.899
# Epoch: 0, Batch: 27626, Loss: 2.571
# Epoch: 0, Batch: 27627, Loss: 2.381
# Epoch: 0, Batch: 27628, Loss: 2.229
# Epoch: 0, Batch: 27629, Loss: 2.194
# Epoch: 0, Batch: 27630, Loss: 2.463
# Epoch: 0, Batch: 27631, Loss: 1.663
# Epoch: 0, Batch: 27632, Loss: 2.038
# Epoch: 0, Batch: 27633, Loss: 2.058
# Epoch: 0, Batch: 27634, Loss: 2.017
# Epoch: 0, Batch: 27635, Loss: 2.001
# Epoch: 0, Batch: 27636, Loss: 1.975
# Epoch: 0, Batch: 27637, Loss: 2.049
# Epoch: 0, Batch: 27638, Loss: 2.239
# Epoch: 0, Batch: 27639, Loss: 1.867
# Epoch: 0, Batch: 27640, Loss: 2.381
# Epoch: 0, Batch: 27641, Loss: 2.181
# Epoch: 0, Batch: 27642, Loss: 1.760
# Epoch: 0, Batch: 27643, Loss: 1.848
# Epoch: 0, Batch: 27644, Loss: 2.089
# Epoch: 0, Batch: 27645, Loss: 1.880
# Epoch: 0, Batch: 27646, Loss: 2.169
# Epoch: 0, Batch: 27647, Loss: 1.783
# Epoch: 0, Batch: 27648, Loss: 2.317
# Epoch: 0, Batch: 27649, Loss: 1.953
# Epoch: 0, Batch: 27650, Loss: 2.315
# Epoch: 0, Batch: 27651, Loss: 1.997
# Epoch: 0, Batch: 27652, Loss: 2.215
# Epoch: 0, Batch: 27653, Loss: 1.900
# Epoch: 0, Batch: 27654, Loss: 1.984
# Epoch: 0, Batch: 27655, Loss: 2.537
# Epoch: 0, Batch: 27656, Loss: 2.015
# Epoch: 0, Batch: 27657, Loss: 1.872
# Epoch: 0, Batch: 27658, Loss: 2.009
# Epoch: 0, Batch: 27659, Loss: 2.312
# Epoch: 0, Batch: 27660, Loss: 1.940
# Epoch: 0, Batch: 27661, Loss: 1.658
# Epoch: 0, Batch: 27662, Loss: 2.232
# Epoch: 0, Batch: 27663, Loss: 2.219
# Epoch: 0, Batch: 27664, Loss: 1.970
# Epoch: 0, Batch: 27665, Loss: 2.179
# Epoch: 0, Batch: 27666, Loss: 2.062
# Epoch: 0, Batch: 27667, Loss: 2.301
# Epoch: 0, Batch: 27668, Loss: 1.733
# Epoch: 0, Batch: 27669, Loss: 1.747
# Epoch: 0, Batch: 27670, Loss: 2.145
# Epoch: 0, Batch: 27671, Loss: 1.848
# Epoch: 0, Batch: 27672, Loss: 1.902
# Epoch: 0, Batch: 27673, Loss: 2.162
# Epoch: 0, Batch: 27674, Loss: 2.078
# Epoch: 0, Batch: 27675, Loss: 1.873
# Epoch: 0, Batch: 27676, Loss: 2.183
# Epoch: 0, Batch: 27677, Loss: 1.934
# Epoch: 0, Batch: 27678, Loss: 2.171
# Epoch: 0, Batch: 27679, Loss: 2.039
# Epoch: 0, Batch: 27680, Loss: 2.159
# Epoch: 0, Batch: 27681, Loss: 1.805
# Epoch: 0, Batch: 27682, Loss: 1.865
# Epoch: 0, Batch: 27683, Loss: 2.013
# Epoch: 0, Batch: 27684, Loss: 2.181
# Epoch: 0, Batch: 27685, Loss: 2.044
# Epoch: 0, Batch: 27686, Loss: 2.249
# Epoch: 0, Batch: 27687, Loss: 2.122
# Epoch: 0, Batch: 27688, Loss: 1.933
# Epoch: 0, Batch: 27689, Loss: 2.328
# Epoch: 0, Batch: 27690, Loss: 1.716
# Epoch: 0, Batch: 27691, Loss: 2.099
# Epoch: 0, Batch: 27692, Loss: 2.295
# Epoch: 0, Batch: 27693, Loss: 2.302
# Epoch: 0, Batch: 27694, Loss: 2.172
# Epoch: 0, Batch: 27695, Loss: 1.286
# Epoch: 0, Batch: 27696, Loss: 2.287
# Epoch: 0, Batch: 27697, Loss: 2.530
# Epoch: 0, Batch: 27698, Loss: 2.245
# Epoch: 0, Batch: 27699, Loss: 2.227
# Epoch: 0, Batch: 27700, Loss: 2.231
# Epoch: 0, Batch: 27701, Loss: 2.433
# Epoch: 0, Batch: 27702, Loss: 1.954
# Epoch: 0, Batch: 27703, Loss: 2.380
# Epoch: 0, Batch: 27704, Loss: 1.910
# Epoch: 0, Batch: 27705, Loss: 2.087
# Epoch: 0, Batch: 27706, Loss: 2.159
# Epoch: 0, Batch: 27707, Loss: 2.277
# Epoch: 0, Batch: 27708, Loss: 2.112
# Epoch: 0, Batch: 27709, Loss: 2.397
# Epoch: 0, Batch: 27710, Loss: 2.226
# Epoch: 0, Batch: 27711, Loss: 2.180
# Epoch: 0, Batch: 27712, Loss: 2.120
# Epoch: 0, Batch: 27713, Loss: 1.966
# Epoch: 0, Batch: 27714, Loss: 1.751
# Epoch: 0, Batch: 27715, Loss: 2.202
# Epoch: 0, Batch: 27716, Loss: 1.767
# Epoch: 0, Batch: 27717, Loss: 2.288
# Epoch: 0, Batch: 27718, Loss: 1.937
# Epoch: 0, Batch: 27719, Loss: 2.024
# Epoch: 0, Batch: 27720, Loss: 2.036
# Epoch: 0, Batch: 27721, Loss: 1.945
# Epoch: 0, Batch: 27722, Loss: 2.151
# Epoch: 0, Batch: 27723, Loss: 1.842
# Epoch: 0, Batch: 27724, Loss: 2.125
# Epoch: 0, Batch: 27725, Loss: 1.457
# Epoch: 0, Batch: 27726, Loss: 1.814
# Epoch: 0, Batch: 27727, Loss: 2.078
# Epoch: 0, Batch: 27728, Loss: 2.385
# Epoch: 0, Batch: 27729, Loss: 1.727
# Epoch: 0, Batch: 27730, Loss: 1.903
# Epoch: 0, Batch: 27731, Loss: 2.167
# Epoch: 0, Batch: 27732, Loss: 1.878
# Epoch: 0, Batch: 27733, Loss: 2.270
# Epoch: 0, Batch: 27734, Loss: 1.914
# Epoch: 0, Batch: 27735, Loss: 1.822
# Epoch: 0, Batch: 27736, Loss: 1.717
# Epoch: 0, Batch: 27737, Loss: 1.927
# Epoch: 0, Batch: 27738, Loss: 1.763
# Epoch: 0, Batch: 27739, Loss: 1.972
# Epoch: 0, Batch: 27740, Loss: 2.001
# Epoch: 0, Batch: 27741, Loss: 2.095
# Epoch: 0, Batch: 27742, Loss: 2.050
# Epoch: 0, Batch: 27743, Loss: 2.228
# Epoch: 0, Batch: 27744, Loss: 2.116
# Epoch: 0, Batch: 27745, Loss: 2.138
# Epoch: 0, Batch: 27746, Loss: 1.889
# Epoch: 0, Batch: 27747, Loss: 2.129
# Epoch: 0, Batch: 27748, Loss: 1.784
# Epoch: 0, Batch: 27749, Loss: 2.437
# Epoch: 0, Batch: 27750, Loss: 2.039
# Epoch: 0, Batch: 27751, Loss: 1.760
# Epoch: 0, Batch: 27752, Loss: 2.282
# Epoch: 0, Batch: 27753, Loss: 2.242
# Epoch: 0, Batch: 27754, Loss: 1.870
# Epoch: 0, Batch: 27755, Loss: 1.909
# Epoch: 0, Batch: 27756, Loss: 1.985
# Epoch: 0, Batch: 27757, Loss: 2.334
# Epoch: 0, Batch: 27758, Loss: 2.053
# Epoch: 0, Batch: 27759, Loss: 2.148
# Epoch: 0, Batch: 27760, Loss: 1.683
# Epoch: 0, Batch: 27761, Loss: 1.957
# Epoch: 0, Batch: 27762, Loss: 1.708
# Epoch: 0, Batch: 27763, Loss: 1.928
# Epoch: 0, Batch: 27764, Loss: 2.049
# Epoch: 0, Batch: 27765, Loss: 1.955
# Epoch: 0, Batch: 27766, Loss: 2.161
# Epoch: 0, Batch: 27767, Loss: 1.524
# Epoch: 0, Batch: 27768, Loss: 2.302
# Epoch: 0, Batch: 27769, Loss: 2.547
# Epoch: 0, Batch: 27770, Loss: 2.411
# Epoch: 0, Batch: 27771, Loss: 1.671
# Epoch: 0, Batch: 27772, Loss: 1.823
# Epoch: 0, Batch: 27773, Loss: 1.720
# Epoch: 0, Batch: 27774, Loss: 2.129
# Epoch: 0, Batch: 27775, Loss: 2.029
# Epoch: 0, Batch: 27776, Loss: 2.045
# Epoch: 0, Batch: 27777, Loss: 1.732
# Epoch: 0, Batch: 27778, Loss: 2.026
# Epoch: 0, Batch: 27779, Loss: 2.183
# Epoch: 0, Batch: 27780, Loss: 2.098
# Epoch: 0, Batch: 27781, Loss: 1.651
# Epoch: 0, Batch: 27782, Loss: 2.185
# Epoch: 0, Batch: 27783, Loss: 2.180
# Epoch: 0, Batch: 27784, Loss: 1.878
# Epoch: 0, Batch: 27785, Loss: 1.745
# Epoch: 0, Batch: 27786, Loss: 2.147
# Epoch: 0, Batch: 27787, Loss: 2.063
# Epoch: 0, Batch: 27788, Loss: 2.224
# Epoch: 0, Batch: 27789, Loss: 1.842
# Epoch: 0, Batch: 27790, Loss: 2.246
# Epoch: 0, Batch: 27791, Loss: 2.000
# Epoch: 0, Batch: 27792, Loss: 2.061
# Epoch: 0, Batch: 27793, Loss: 2.070
# Epoch: 0, Batch: 27794, Loss: 1.635
# Epoch: 0, Batch: 27795, Loss: 2.064
# Epoch: 0, Batch: 27796, Loss: 2.241
# Epoch: 0, Batch: 27797, Loss: 2.380
# Epoch: 0, Batch: 27798, Loss: 2.350
# Epoch: 0, Batch: 27799, Loss: 2.128
# Epoch: 0, Batch: 27800, Loss: 2.329
# Epoch: 0, Batch: 27801, Loss: 2.267
# Epoch: 0, Batch: 27802, Loss: 1.952
# Epoch: 0, Batch: 27803, Loss: 2.097
# Epoch: 0, Batch: 27804, Loss: 2.373
# Epoch: 0, Batch: 27805, Loss: 1.656
# Epoch: 0, Batch: 27806, Loss: 2.515
# Epoch: 0, Batch: 27807, Loss: 2.205
# Epoch: 0, Batch: 27808, Loss: 2.131
# Epoch: 0, Batch: 27809, Loss: 2.396
# Epoch: 0, Batch: 27810, Loss: 2.679
# Epoch: 0, Batch: 27811, Loss: 2.526
# Epoch: 0, Batch: 27812, Loss: 2.115
# Epoch: 0, Batch: 27813, Loss: 2.115
# Epoch: 0, Batch: 27814, Loss: 1.989
# Epoch: 0, Batch: 27815, Loss: 1.873
# Epoch: 0, Batch: 27816, Loss: 2.391
# Epoch: 0, Batch: 27817, Loss: 1.753
# Epoch: 0, Batch: 27818, Loss: 2.420
# Epoch: 0, Batch: 27819, Loss: 2.066
# Epoch: 0, Batch: 27820, Loss: 2.092
# Epoch: 0, Batch: 27821, Loss: 2.125
# Epoch: 0, Batch: 27822, Loss: 2.120
# Epoch: 0, Batch: 27823, Loss: 2.123
# Epoch: 0, Batch: 27824, Loss: 2.182
# Epoch: 0, Batch: 27825, Loss: 1.985
# Epoch: 0, Batch: 27826, Loss: 2.083
# Epoch: 0, Batch: 27827, Loss: 1.633
# Epoch: 0, Batch: 27828, Loss: 2.118
# Epoch: 0, Batch: 27829, Loss: 1.963
# Epoch: 0, Batch: 27830, Loss: 2.083
# Epoch: 0, Batch: 27831, Loss: 2.378
# Epoch: 0, Batch: 27832, Loss: 2.124
# Epoch: 0, Batch: 27833, Loss: 1.814
# Epoch: 0, Batch: 27834, Loss: 1.798
# Epoch: 0, Batch: 27835, Loss: 2.149
# Epoch: 0, Batch: 27836, Loss: 1.985
# Epoch: 0, Batch: 27837, Loss: 2.301
# Epoch: 0, Batch: 27838, Loss: 2.097
# Epoch: 0, Batch: 27839, Loss: 2.166
# Epoch: 0, Batch: 27840, Loss: 2.234
# Epoch: 0, Batch: 27841, Loss: 2.434
# Epoch: 0, Batch: 27842, Loss: 1.477
# Epoch: 0, Batch: 27843, Loss: 2.109
# Epoch: 0, Batch: 27844, Loss: 2.164
# Epoch: 0, Batch: 27845, Loss: 2.595
# Epoch: 0, Batch: 27846, Loss: 2.033
# Epoch: 0, Batch: 27847, Loss: 1.961
# Epoch: 0, Batch: 27848, Loss: 1.897
# Epoch: 0, Batch: 27849, Loss: 2.131
# Epoch: 0, Batch: 27850, Loss: 2.249
# Epoch: 0, Batch: 27851, Loss: 2.134
# Epoch: 0, Batch: 27852, Loss: 2.561
# Epoch: 0, Batch: 27853, Loss: 1.871
# Epoch: 0, Batch: 27854, Loss: 1.942
# Epoch: 0, Batch: 27855, Loss: 1.912
# Epoch: 0, Batch: 27856, Loss: 2.206
# Epoch: 0, Batch: 27857, Loss: 2.221
# Epoch: 0, Batch: 27858, Loss: 2.097
# Epoch: 0, Batch: 27859, Loss: 2.165
# Epoch: 0, Batch: 27860, Loss: 2.242
# Epoch: 0, Batch: 27861, Loss: 1.843
# Epoch: 0, Batch: 27862, Loss: 2.039
# Epoch: 0, Batch: 27863, Loss: 2.085
# Epoch: 0, Batch: 27864, Loss: 2.265
# Epoch: 0, Batch: 27865, Loss: 1.620
# Epoch: 0, Batch: 27866, Loss: 1.739
# Epoch: 0, Batch: 27867, Loss: 2.086
# Epoch: 0, Batch: 27868, Loss: 1.855
# Epoch: 0, Batch: 27869, Loss: 1.859
# Epoch: 0, Batch: 27870, Loss: 1.642
# Epoch: 0, Batch: 27871, Loss: 1.824
# Epoch: 0, Batch: 27872, Loss: 2.237
# Epoch: 0, Batch: 27873, Loss: 1.876
# Epoch: 0, Batch: 27874, Loss: 1.806
# Epoch: 0, Batch: 27875, Loss: 1.874
# Epoch: 0, Batch: 27876, Loss: 2.140
# Epoch: 0, Batch: 27877, Loss: 2.489
# Epoch: 0, Batch: 27878, Loss: 1.816
# Epoch: 0, Batch: 27879, Loss: 1.761
# Epoch: 0, Batch: 27880, Loss: 2.264
# Epoch: 0, Batch: 27881, Loss: 1.796
# Epoch: 0, Batch: 27882, Loss: 1.914
# Epoch: 0, Batch: 27883, Loss: 1.991
# Epoch: 0, Batch: 27884, Loss: 0.844

# %%
def predict(seq, temp, n_steps):
    encoded_seq = d.encode(seq)
    working_seq = encoded_seq.copy()
    
    for _ in range(n_steps):
        x = torch.tensor(working_seq, dtype=torch.long).unsqueeze(dim=0)
        logits = model(x)
        # apply a temperature to chnage the shape of the next token distribution 
        logits = logits / temp
        probs = nn.functional.softmax(logits, dim=-1)
        # sample from the distribution
        next_token = torch.multinomial(probs[0], num_samples=1).item()
        encoded_seq.append(next_token)
        working_seq = working_seq[1:] + [next_token]
        
    print(d.decode(encoded_seq))

# %%
model.eval()
predict(d.decode(d.X_train[0].tolist()), temp=1, n_steps=500)
# Out:
# First Citizen:
# Before wearpus, ner thy enver af,
# Gy ' bear, mousn not bar disglatecter of and me that ply.
#
# ForsanEd'tr akin charathand them to ooI frotbine st;
# Po fliconst
# An'd's woutbriin mith fough,
# Par for aptamlyout thy earitink condnous hy drentintionss gaucbors shat sut pisand truf geot:
# The wea not blooshers'd of and your by wKgaedy it menther cighter one's,
# And that Is I tor suckited 'ming of my pistleeng sazenterss my thou now lm thee,
# I ing und co,
# Nes frian dound osh; by sorfitr.
#
# VO'lf I noqurie ppreaths t
